# %% [markdown]
# ## Build an end-to-end ML workflow with the AWS Step Functions Data Science SDK
# ### Glovo Use Case: Industrializing a sample XGBoost model in AWS - Courier default

# %% [markdown]
# **Glovo's courier default description:**
#
# We define courier default when a courier collects a high amount of cash and then leaves the company without returning the money.
#
# - By leaving the company we define as not having any interaction with Glovo during 28 consecutive days since the last delivered order.
# - Each region/city/country has a threshold to designate a high amount of cash defined by the business.
#
# The business request made to the Data Science team is to design a machine learning system to detect when a courier is likely to incur in default before they actually default or before the amount of cash balance is too high.
#
# The proposed definition is to deliver a default score for each courier every week. For that we created a label for each courier on a window time, so we can identify some defaulters and then fit a xgboost classifier to predict on current couriers.
#
# -------
#
# ***Please make sure you follow the steps for creating the AWS IAM roles required before running this notebook. These are used in the Amazon SageMaker notebook for interacting with other services like AWS Step Functions and AWS Lambda.***
#
# **Architecture:**
#
# Note the Data Scientists will use this notebook with Python 3 and the AWS Step Functions Data Science SDK installed for creating the ML workflow. We will also use AWS Lambda for some handy functions in the workflow.
#
# <img src="./sample_architecture.jpg" width="60%">
#
# *For more information on how to create a notebook or how to install the Data Science SDK you can check the documentation* [here](https://aws-step-functions-data-science-sdk.readthedocs.io/en/latest/readmelink.html#getting-started-with-sample-jupyter-notebooks).

# %%
# Install/upgrade the stepfunctions library...
import sys
# !{sys.executable} -m pip install --upgrade stepfunctions
# Out:
# Requirement already up-to-date: stepfunctions in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (1.1.0)
# Requirement already satisfied, skipping upgrade: pyyaml in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from stepfunctions) (5.3.1)
# Requirement already satisfied, skipping upgrade: boto3>=1.9.213 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from stepfunctions) (1.14.31)
# Requirement already satisfied, skipping upgrade: sagemaker>=1.42.8 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from stepfunctions) (1.71.0)
# Requirement already satisfied, skipping upgrade: jmespath<1.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3>=1.9.213->stepfunctions) (0.9.4)
# Requirement already satisfied, skipping upgrade: botocore<1.18.0,>=1.17.31 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3>=1.9.213->stepfunctions) (1.17.31)
# Requirement already satisfied, skipping upgrade: s3transfer<0.4.0,>=0.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3>=1.9.213->stepfunctions) (0.3.3)
# Requirement already satisfied, skipping upgrade: protobuf>=3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker>=1.42.8->stepfunctions) (3.12.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker>=1.42.8->stepfunctions) (1.18.1)
# Requirement already satisfied, skipping upgrade: protobuf3-to-dict>=0.1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker>=1.42.8->stepfunctions) (0.1.5)
# Requirement already satisfied, skipping upgrade: packaging>=20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker>=1.42.8->stepfunctions) (20.3)
# Requirement already satisfied, skipping upgrade: smdebug-rulesconfig==0.1.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker>=1.42.8->stepfunctions) (0.1.4)
# Requirement already satisfied, skipping upgrade: importlib-metadata>=1.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker>=1.42.8->stepfunctions) (1.5.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker>=1.42.8->stepfunctions) (1.4.1)
# Requirement already satisfied, skipping upgrade: urllib3<1.26,>=1.20 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore<1.18.0,>=1.17.31->boto3>=1.9.213->stepfunctions) (1.25.8)
# Requirement already satisfied, skipping upgrade: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore<1.18.0,>=1.17.31->boto3>=1.9.213->stepfunctions) (2.8.1)
# Requirement already satisfied, skipping upgrade: docutils<0.16,>=0.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore<1.18.0,>=1.17.31->boto3>=1.9.213->stepfunctions) (0.15.2)
# Requirement already satisfied, skipping upgrade: six>=1.9 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from protobuf>=3.1->sagemaker>=1.42.8->stepfunctions) (1.14.0)
# Requirement already satisfied, skipping upgrade: setuptools in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from protobuf>=3.1->sagemaker>=1.42.8->stepfunctions) (46.1.3.post20200330)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from packaging>=20.0->sagemaker>=1.42.8->stepfunctions) (2.4.6)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata>=1.4.0->sagemaker>=1.42.8->stepfunctions) (2.2.0)
# WARNING: You are using pip version 20.0.2; however, version 20.2 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# ----------------
#
# ### Preparation
# Let us start by loading some libraries and setting up the roles on the notebook.
#
# ***--- NOTE: Make sure you replace with your bucket info and role ARNs in the placeholders below! ---***

# %%
import boto3, sagemaker, time, random, uuid, logging, stepfunctions, io, random

from sagemaker.amazon.amazon_estimator import get_image_uri
from stepfunctions import steps
from stepfunctions.steps import TrainingStep, ModelStep, TransformStep
from stepfunctions.inputs import ExecutionInput
from stepfunctions.workflow import Workflow
from stepfunctions.template import TrainingPipeline
from stepfunctions.template.utils import replace_parameters_with_jsonpath

sagemaker_execution_role = sagemaker.get_execution_role()
session = sagemaker.Session()
stepfunctions.set_stream_logger(level=logging.INFO)

###### REPLACE THE INFO IN THE PLACEHOLDERS ######
###################################################
# Replace with your AWS StepFunctions WorkflowExecutionRole ARN, and with your AWS Lambda role ARN...
workflow_execution_role = "arn:aws:iam::889960878219:role/StepFunctionsWorkflowExecutionRole"
lambda_role = "arn:aws:iam::889960878219:role/LambdaDynamo"
# Replace with your Amazon S3 bucket name, prefix, and dataset filename...
bucket = 'antonio-rodriguez-workshop'
prefix = 'glovo/workflow'
filename = 'joint_dataframe.csv'
###################################################

print('Using AWS StepFunctions and AWS Lambda roles:\n {}\n {}\n'.format(workflow_execution_role, lambda_role))
print('Using dataset location in Amazon S3:\n https://s3.console.aws.amazon.com/s3/buckets/{}/{}/{}'.format(bucket, prefix, filename))
# Out:
# Using StepFunctions and Lambda roles:
#  arn:aws:iam::889960878219:role/StepFunctionsWorkflowExecutionRole
#  arn:aws:iam::889960878219:role/LambdaDynamo
#
# Using dataset in S3:
#  https://s3.console.aws.amazon.com/s3/buckets/antonio-rodriguez-workshop/glovo/workflow/joint_dataframe.csv

# %% [markdown]
# --------
#
# ### Pre-processing

# %% [markdown]
# #### Automating data preparation with AWS Lambda
#
# Prepare a script for running your sample feature engineering. We will use an AWS Lambda function for this because we want to automate as much as possible.

# %%
# Create data pre-processing AWS Lambda:

# First download Pandas and Numpy for using in our AWS Lambda package, as these do not come in AWS Lambda's base...
import os
from urllib.request import urlretrieve 
# !mkdir lambda
urlretrieve("https://files.pythonhosted.org/packages/7b/fd/41698f20fd297cef2dc43a72a8ca42d149eaf7d954f1fb2bd3fc366a658d/pandas-0.25.3-cp38-cp38-manylinux1_x86_64.whl", "lambda/pandas-0.25.3-cp38-cp38-manylinux1_x86_64.whl")
urlretrieve("https://files.pythonhosted.org/packages/d7/6a/3fed132c846d1e47963f30376cc041e9dd586d286d931055ad06ff65c6c7/numpy-1.17.4-cp38-cp38-manylinux1_x86_64.whl", "lambda/numpy-1.17.4-cp38-cp38-manylinux1_x86_64.whl")
# !unzip -o lambda/pandas-0.25.3-cp38-cp38-manylinux1_x86_64.whl -d lambda
# !unzip -o lambda/numpy-1.17.4-cp38-cp38-manylinux1_x86_64.whl -d lambda

# then install the pytz dependency locally...
# !pip install -t lambda pytz
# and remove the files no longer needed...
# !rm -rf lambda/*.whl lambda/*.dist-info lambda/__pycache__

# prepare the Lambda function code for your pre-processing script...
file_name = 'lambda/lambda_function.py'
def MakeFile(file_name):
    with open(file_name, 'w') as f:
        f.write('''\
import json
import boto3
import pandas
import numpy as np
import os
bucket = os.environ['BUCKET']
prefix = os.environ['PREFIX']
filename = os.environ['FILENAME']
def lambda_handler(event, context):
    s3 = boto3.resource('s3')
    s3.Bucket(bucket).download_file(prefix + "/" + filename, '/tmp/' + filename)
    df = pandas.read_csv("/tmp/" + filename)
    cols = [0, 1, 2, 3, 4, 5, 6, 8, 56, 191, 201, 203, 206, 209, 218, 220]
    df.drop(df.columns[cols],axis=1,inplace=True)
    df = pandas.concat([df['is_defaulter'], df.drop(['is_defaulter'], axis=1)], axis=1)
    train_data, validation_data, test_data = np.split(df.sample(frac=1, random_state=1729), [int(0.7 * len(df)), int(0.9 * len(df))])
    train_data.to_csv('/tmp/train.csv', header=False, index=False)
    validation_data.to_csv('/tmp/validation.csv', header=False, index=False)
    test_data.to_csv('/tmp/test_real.csv', header=False, index=False)
    test_data.drop(['is_defaulter'], axis=1).to_csv('/tmp/test.csv', header=False, index=False)
    s3.Bucket(bucket).Object(os.path.join(prefix, 'train/train.csv')).upload_file('/tmp/train.csv')
    s3.Bucket(bucket).Object(os.path.join(prefix, 'validation/validation.csv')).upload_file('/tmp/validation.csv')
    s3.Bucket(bucket).Object(os.path.join(prefix, 'test/test.csv')).upload_file('/tmp/test.csv')
    return {
        'statusCode': 200,
        'body': ('Date pre-processing complete for ' + filename + ' - ' + bucket + '/' + prefix + '/' + filename)
    }
        ''')
MakeFile(file_name)

# finally, create the runtime file with Pandas, Numpy, and your pre-processing code...
import zipfile
def zipFilesInDir(dirName, zipFileName):
   # create the zip file...
   with zipfile.ZipFile(zipFileName, 'w', zipfile.ZIP_DEFLATED) as zipObj:
        # iterate over all the files in the directory
        #folder = os.path.abspath(dirName)
        #os.chdir(folder)
        for folderName, subfolders, filenames in os.walk(dirName):
            for filename in filenames:
               # create complete filepath of file in directory
               filePath = os.path.join(folderName, filename)
               # add file to zip
               zipObj.write(filePath, arcname=os.path.join(os.path.relpath(folderName, os.path.abspath(dirName)), filename))
zipFilesInDir('lambda', 'lambda_function.zip')
# !rm -fr lambda

try:
    f = open("lambda_function.zip")
    print("Lambda file created: lambda_function.zip")
except IOError:
    print("Error - Lambda file not created")
finally:
    f.close()

# load the zip file as binary code...
with open('lambda_function.zip', 'rb') as f: 
    code = f.read()

# and create the AWS Lambda function...
client = boto3.client('lambda')
create_lambda_function = client.create_function(
    FunctionName = 'glovo-pre-processing',
    Runtime = 'python3.8',
    Role = lambda_role,
    Description = 'Sample ML pipeline data pre-processing lambda',
    Code = {'ZipFile': code},
    Handler='{}.lambda_handler'.format('lambda_function'),
    Timeout = 600,
    MemorySize = 1024,
    Environment = {
        'Variables': {
            'BUCKET': bucket,
            'PREFIX': prefix,
            'FILENAME': filename
        }
    }
)
# Out:
# Archive:  lambda/pandas-0.25.3-cp38-cp38-manylinux1_x86_64.whl
#   inflating: lambda/pandas-0.25.3.dist-info/METADATA
#   inflating: lambda/pandas-0.25.3.dist-info/entry_points.txt
#   inflating: lambda/pandas-0.25.3.dist-info/RECORD
#   inflating: lambda/pandas-0.25.3.dist-info/WHEEL
#   inflating: lambda/pandas-0.25.3.dist-info/top_level.txt
#   inflating: lambda/pandas/testing.py
#   inflating: lambda/pandas/_version.py
#   inflating: lambda/pandas/__init__.py
#   inflating: lambda/pandas/_typing.py
#   inflating: lambda/pandas/conftest.py
#   inflating: lambda/pandas/tseries/frequencies.py
#   inflating: lambda/pandas/tseries/offsets.py
#   inflating: lambda/pandas/tseries/converter.py
#   inflating: lambda/pandas/tseries/plotting.py
#   inflating: lambda/pandas/tseries/api.py
#   inflating: lambda/pandas/tseries/__init__.py
#   inflating: lambda/pandas/tseries/holiday.py
#   inflating: lambda/pandas/tests/test_join.py
#   inflating: lambda/pandas/tests/test_downstream.py
#   inflating: lambda/pandas/tests/test_strings.py
#   inflating: lambda/pandas/tests/test_lib.py
#   inflating: lambda/pandas/tests/test_base.py
#   inflating: lambda/pandas/tests/test_multilevel.py
#   inflating: lambda/pandas/tests/test_nanops.py
#   inflating: lambda/pandas/tests/test_common.py
#   inflating: lambda/pandas/tests/test_errors.py
#   inflating: lambda/pandas/tests/test_algos.py
#   inflating: lambda/pandas/tests/test_sorting.py
#   inflating: lambda/pandas/tests/test_take.py
#   inflating: lambda/pandas/tests/test_register_accessor.py
#   inflating: lambda/pandas/tests/__init__.py
#   inflating: lambda/pandas/tests/test_compat.py
#   inflating: lambda/pandas/tests/test_expressions.py
#   inflating: lambda/pandas/tests/test_optional_dependency.py
#   inflating: lambda/pandas/tests/computation/test_eval.py
#   inflating: lambda/pandas/tests/computation/__init__.py
#   inflating: lambda/pandas/tests/computation/test_compat.py
#   inflating: lambda/pandas/tests/window/common.py
#   inflating: lambda/pandas/tests/window/test_timeseries_window.py
#   inflating: lambda/pandas/tests/window/test_expanding.py
#   inflating: lambda/pandas/tests/window/test_window.py
#   inflating: lambda/pandas/tests/window/test_ewm.py
#   inflating: lambda/pandas/tests/window/test_grouper.py
#   inflating: lambda/pandas/tests/window/test_pairwise.py
#   inflating: lambda/pandas/tests/window/test_dtypes.py
#   inflating: lambda/pandas/tests/window/test_api.py
#   inflating: lambda/pandas/tests/window/test_rolling.py
#   inflating: lambda/pandas/tests/window/test_moments.py
#   inflating: lambda/pandas/tests/window/__init__.py
#   inflating: lambda/pandas/tests/window/conftest.py
#   inflating: lambda/pandas/tests/indexes/common.py
#   inflating: lambda/pandas/tests/indexes/test_numpy_compat.py
#   inflating: lambda/pandas/tests/indexes/datetimelike.py
#   inflating: lambda/pandas/tests/indexes/test_setops.py
#   inflating: lambda/pandas/tests/indexes/test_numeric.py
#   inflating: lambda/pandas/tests/indexes/test_frozen.py
#   inflating: lambda/pandas/tests/indexes/test_base.py
#   inflating: lambda/pandas/tests/indexes/test_common.py
#   inflating: lambda/pandas/tests/indexes/test_category.py
#   inflating: lambda/pandas/tests/indexes/__init__.py
#   inflating: lambda/pandas/tests/indexes/conftest.py
#   inflating: lambda/pandas/tests/indexes/test_range.py
#   inflating: lambda/pandas/tests/indexes/multi/test_get_set.py
#   inflating: lambda/pandas/tests/indexes/multi/test_drop.py
#   inflating: lambda/pandas/tests/indexes/multi/test_reshape.py
#   inflating: lambda/pandas/tests/indexes/multi/test_join.py
#   inflating: lambda/pandas/tests/indexes/multi/test_duplicates.py
#   inflating: lambda/pandas/tests/indexes/multi/test_monotonic.py
#   inflating: lambda/pandas/tests/indexes/multi/test_reindex.py
#   inflating: lambda/pandas/tests/indexes/multi/test_missing.py
#   inflating: lambda/pandas/tests/indexes/multi/test_analytics.py
#   inflating: lambda/pandas/tests/indexes/multi/test_indexing.py
#   inflating: lambda/pandas/tests/indexes/multi/test_format.py
#   inflating: lambda/pandas/tests/indexes/multi/test_set_ops.py
#   inflating: lambda/pandas/tests/indexes/multi/test_equivalence.py
#   inflating: lambda/pandas/tests/indexes/multi/test_conversion.py
#   inflating: lambda/pandas/tests/indexes/multi/test_copy.py
#   inflating: lambda/pandas/tests/indexes/multi/test_sorting.py
#   inflating: lambda/pandas/tests/indexes/multi/test_names.py
#   inflating: lambda/pandas/tests/indexes/multi/test_partial_indexing.py
#   inflating: lambda/pandas/tests/indexes/multi/test_integrity.py
#   inflating: lambda/pandas/tests/indexes/multi/test_contains.py
#   inflating: lambda/pandas/tests/indexes/multi/__init__.py
#   inflating: lambda/pandas/tests/indexes/multi/test_compat.py
#   inflating: lambda/pandas/tests/indexes/multi/test_constructor.py
#   inflating: lambda/pandas/tests/indexes/multi/conftest.py
#   inflating: lambda/pandas/tests/indexes/multi/test_astype.py
#   inflating: lambda/pandas/tests/indexes/period/test_period_range.py
#   inflating: lambda/pandas/tests/indexes/period/test_scalar_compat.py
#   inflating: lambda/pandas/tests/indexes/period/test_setops.py
#   inflating: lambda/pandas/tests/indexes/period/test_period.py
#   inflating: lambda/pandas/tests/indexes/period/test_formats.py
#   inflating: lambda/pandas/tests/indexes/period/test_asfreq.py
#   inflating: lambda/pandas/tests/indexes/period/test_indexing.py
#   inflating: lambda/pandas/tests/indexes/period/test_tools.py
#   inflating: lambda/pandas/tests/indexes/period/test_ops.py
#   inflating: lambda/pandas/tests/indexes/period/test_partial_slicing.py
#   inflating: lambda/pandas/tests/indexes/period/__init__.py
#   inflating: lambda/pandas/tests/indexes/period/test_construction.py
#   inflating: lambda/pandas/tests/indexes/period/test_arithmetic.py
#   inflating: lambda/pandas/tests/indexes/period/test_astype.py
#   inflating: lambda/pandas/tests/indexes/datetimes/test_scalar_compat.py
#   inflating: lambda/pandas/tests/indexes/datetimes/test_setops.py
#   inflating: lambda/pandas/tests/indexes/datetimes/test_datetimelike.py
#   inflating: lambda/pandas/tests/indexes/datetimes/test_formats.py
#   inflating: lambda/pandas/tests/indexes/datetimes/test_timezones.py
#   inflating: lambda/pandas/tests/indexes/datetimes/test_misc.py
#   inflating: lambda/pandas/tests/indexes/datetimes/test_missing.py
#   inflating: lambda/pandas/tests/indexes/datetimes/test_indexing.py
#   inflating: lambda/pandas/tests/indexes/datetimes/test_tools.py
#   inflating: lambda/pandas/tests/indexes/datetimes/test_date_range.py
#   inflating: lambda/pandas/tests/indexes/datetimes/test_ops.py
#   inflating: lambda/pandas/tests/indexes/datetimes/test_datetime.py
#   inflating: lambda/pandas/tests/indexes/datetimes/test_partial_slicing.py
#   inflating: lambda/pandas/tests/indexes/datetimes/__init__.py
#   inflating: lambda/pandas/tests/indexes/datetimes/test_construction.py
#   inflating: lambda/pandas/tests/indexes/datetimes/test_arithmetic.py
#   inflating: lambda/pandas/tests/indexes/datetimes/test_astype.py
#   inflating: lambda/pandas/tests/indexes/interval/test_interval_range.py
#   inflating: lambda/pandas/tests/indexes/interval/test_setops.py
#   inflating: lambda/pandas/tests/indexes/interval/test_interval_tree.py
#   inflating: lambda/pandas/tests/indexes/interval/test_interval.py
#   inflating: lambda/pandas/tests/indexes/interval/__init__.py
#   inflating: lambda/pandas/tests/indexes/interval/test_construction.py
#   inflating: lambda/pandas/tests/indexes/interval/test_interval_new.py
#   inflating: lambda/pandas/tests/indexes/interval/test_astype.py
#   inflating: lambda/pandas/tests/indexes/timedeltas/test_scalar_compat.py
#   inflating: lambda/pandas/tests/indexes/timedeltas/test_setops.py
#   inflating: lambda/pandas/tests/indexes/timedeltas/test_timedelta_range.py
#   inflating: lambda/pandas/tests/indexes/timedeltas/test_formats.py
#   inflating: lambda/pandas/tests/indexes/timedeltas/test_indexing.py
#   inflating: lambda/pandas/tests/indexes/timedeltas/test_tools.py
#   inflating: lambda/pandas/tests/indexes/timedeltas/test_ops.py
#   inflating: lambda/pandas/tests/indexes/timedeltas/test_timedelta.py
#   inflating: lambda/pandas/tests/indexes/timedeltas/test_partial_slicing.py
#   inflating: lambda/pandas/tests/indexes/timedeltas/__init__.py
#   inflating: lambda/pandas/tests/indexes/timedeltas/test_construction.py
#   inflating: lambda/pandas/tests/indexes/timedeltas/test_arithmetic.py
#   inflating: lambda/pandas/tests/indexes/timedeltas/test_astype.py
#   inflating: lambda/pandas/tests/frame/common.py
#   inflating: lambda/pandas/tests/frame/test_reshape.py
#   inflating: lambda/pandas/tests/frame/test_join.py
#   inflating: lambda/pandas/tests/frame/test_convert_to.py
#   inflating: lambda/pandas/tests/frame/test_combine_concat.py
#   inflating: lambda/pandas/tests/frame/test_explode.py
#   inflating: lambda/pandas/tests/frame/test_sort_values_level_as_str.py
#   inflating: lambda/pandas/tests/frame/test_duplicates.py
#   inflating: lambda/pandas/tests/frame/test_axis_select_reindex.py
#   inflating: lambda/pandas/tests/frame/test_rank.py
#   inflating: lambda/pandas/tests/frame/test_subclass.py
#   inflating: lambda/pandas/tests/frame/test_period.py
#   inflating: lambda/pandas/tests/frame/test_replace.py
#   inflating: lambda/pandas/tests/frame/test_timezones.py
#   inflating: lambda/pandas/tests/frame/test_nonunique_indexes.py
#   inflating: lambda/pandas/tests/frame/test_missing.py
#   inflating: lambda/pandas/tests/frame/test_analytics.py
#   inflating: lambda/pandas/tests/frame/test_indexing.py
#   inflating: lambda/pandas/tests/frame/test_apply.py
#   inflating: lambda/pandas/tests/frame/test_constructors.py
#   inflating: lambda/pandas/tests/frame/test_dtypes.py
#   inflating: lambda/pandas/tests/frame/test_query_eval.py
#   inflating: lambda/pandas/tests/frame/test_sorting.py
#   inflating: lambda/pandas/tests/frame/test_to_csv.py
#   inflating: lambda/pandas/tests/frame/test_api.py
#   inflating: lambda/pandas/tests/frame/test_asof.py
#   inflating: lambda/pandas/tests/frame/test_quantile.py
#   inflating: lambda/pandas/tests/frame/test_repr_info.py
#   inflating: lambda/pandas/tests/frame/test_operators.py
#   inflating: lambda/pandas/tests/frame/__init__.py
#   inflating: lambda/pandas/tests/frame/test_timeseries.py
#   inflating: lambda/pandas/tests/frame/test_arithmetic.py
#   inflating: lambda/pandas/tests/frame/test_alter_axes.py
#   inflating: lambda/pandas/tests/frame/test_mutate_columns.py
#   inflating: lambda/pandas/tests/frame/conftest.py
#   inflating: lambda/pandas/tests/frame/test_block_internals.py
#   inflating: lambda/pandas/tests/frame/test_validate.py
#   inflating: lambda/pandas/tests/config/test_config.py
#   inflating: lambda/pandas/tests/config/test_localization.py
#   inflating: lambda/pandas/tests/config/__init__.py
#   inflating: lambda/pandas/tests/tseries/__init__.py
#   inflating: lambda/pandas/tests/tseries/offsets/test_offsets_properties.py
#   inflating: lambda/pandas/tests/tseries/offsets/common.py
#   inflating: lambda/pandas/tests/tseries/offsets/test_yqm_offsets.py
#   inflating: lambda/pandas/tests/tseries/offsets/test_fiscal.py
#   inflating: lambda/pandas/tests/tseries/offsets/test_offsets.py
#   inflating: lambda/pandas/tests/tseries/offsets/test_ticks.py
#   inflating: lambda/pandas/tests/tseries/offsets/__init__.py
#   inflating: lambda/pandas/tests/tseries/offsets/conftest.py
#   inflating: lambda/pandas/tests/tseries/holiday/test_observance.py
#   inflating: lambda/pandas/tests/tseries/holiday/test_federal.py
#   inflating: lambda/pandas/tests/tseries/holiday/test_calendar.py
#   inflating: lambda/pandas/tests/tseries/holiday/__init__.py
#   inflating: lambda/pandas/tests/tseries/holiday/test_holiday.py
#   inflating: lambda/pandas/tests/tseries/frequencies/test_inference.py
#   inflating: lambda/pandas/tests/tseries/frequencies/test_freq_code.py
#   inflating: lambda/pandas/tests/tseries/frequencies/__init__.py
#   inflating: lambda/pandas/tests/tseries/frequencies/test_to_offset.py
#   inflating: lambda/pandas/tests/resample/test_resampler_grouper.py
#   inflating: lambda/pandas/tests/resample/test_base.py
#   inflating: lambda/pandas/tests/resample/test_time_grouper.py
#   inflating: lambda/pandas/tests/resample/test_period_index.py
#   inflating: lambda/pandas/tests/resample/test_datetime_index.py
#   inflating: lambda/pandas/tests/resample/test_timedelta.py
#   inflating: lambda/pandas/tests/resample/__init__.py
#   inflating: lambda/pandas/tests/resample/test_resample_api.py
#   inflating: lambda/pandas/tests/resample/conftest.py
#   inflating: lambda/pandas/tests/arithmetic/test_numeric.py
#   inflating: lambda/pandas/tests/arithmetic/test_period.py
#   inflating: lambda/pandas/tests/arithmetic/test_datetime64.py
#   inflating: lambda/pandas/tests/arithmetic/test_object.py
#   inflating: lambda/pandas/tests/arithmetic/__init__.py
#   inflating: lambda/pandas/tests/arithmetic/test_timedelta64.py
#   inflating: lambda/pandas/tests/arithmetic/conftest.py
#   inflating: lambda/pandas/tests/tslibs/test_timedeltas.py
#   inflating: lambda/pandas/tests/tslibs/test_liboffsets.py
#   inflating: lambda/pandas/tests/tslibs/test_timezones.py
#   inflating: lambda/pandas/tests/tslibs/test_ccalendar.py
#   inflating: lambda/pandas/tests/tslibs/test_libfrequencies.py
#   inflating: lambda/pandas/tests/tslibs/test_parsing.py
#   inflating: lambda/pandas/tests/tslibs/test_conversion.py
#   inflating: lambda/pandas/tests/tslibs/test_parse_iso8601.py
#   inflating: lambda/pandas/tests/tslibs/test_api.py
#   inflating: lambda/pandas/tests/tslibs/test_array_to_datetime.py
#   inflating: lambda/pandas/tests/tslibs/test_period_asfreq.py
#   inflating: lambda/pandas/tests/tslibs/__init__.py
#   inflating: lambda/pandas/tests/tslibs/test_normalize_date.py
#   inflating: lambda/pandas/tests/io/test_s3.py
#   inflating: lambda/pandas/tests/io/test_parquet.py
#   inflating: lambda/pandas/tests/io/test_html.py
#   inflating: lambda/pandas/tests/io/test_pickle.py
#   inflating: lambda/pandas/tests/io/test_spss.py
#   inflating: lambda/pandas/tests/io/test_clipboard.py
#   inflating: lambda/pandas/tests/io/test_stata.py
#   inflating: lambda/pandas/tests/io/test_common.py
#   inflating: lambda/pandas/tests/io/test_compression.py
#   inflating: lambda/pandas/tests/io/generate_legacy_storage_files.py
#   inflating: lambda/pandas/tests/io/test_packers.py
#   inflating: lambda/pandas/tests/io/test_feather.py
#   inflating: lambda/pandas/tests/io/test_gcs.py
#   inflating: lambda/pandas/tests/io/test_gbq.py
#   inflating: lambda/pandas/tests/io/test_sql.py
#   inflating: lambda/pandas/tests/io/__init__.py
#   inflating: lambda/pandas/tests/io/test_date_converters.py
#   inflating: lambda/pandas/tests/io/conftest.py
#   inflating: lambda/pandas/tests/io/pytables/test_pytables.py
#   inflating: lambda/pandas/tests/io/pytables/test_pytables_missing.py
#   inflating: lambda/pandas/tests/io/pytables/__init__.py
#   inflating: lambda/pandas/tests/io/pytables/test_compat.py
#   inflating: lambda/pandas/tests/io/formats/test_to_html.py
#   inflating: lambda/pandas/tests/io/formats/test_css.py
#   inflating: lambda/pandas/tests/io/formats/test_eng_formatting.py
#   inflating: lambda/pandas/tests/io/formats/test_format.py
#   inflating: lambda/pandas/tests/io/formats/test_to_excel.py
#   inflating: lambda/pandas/tests/io/formats/test_to_csv.py
#   inflating: lambda/pandas/tests/io/formats/test_console.py
#   inflating: lambda/pandas/tests/io/formats/__init__.py
#   inflating: lambda/pandas/tests/io/formats/test_printing.py
#   inflating: lambda/pandas/tests/io/formats/test_to_latex.py
#   inflating: lambda/pandas/tests/io/formats/test_style.py
#   inflating: lambda/pandas/tests/io/msgpack/common.py
#   inflating: lambda/pandas/tests/io/msgpack/test_read_size.py
#   inflating: lambda/pandas/tests/io/msgpack/test_newspec.py
#   inflating: lambda/pandas/tests/io/msgpack/test_limits.py
#   inflating: lambda/pandas/tests/io/msgpack/test_obj.py
#   inflating: lambda/pandas/tests/io/msgpack/test_extension.py
#   inflating: lambda/pandas/tests/io/msgpack/test_format.py
#   inflating: lambda/pandas/tests/io/msgpack/test_pack.py
#   inflating: lambda/pandas/tests/io/msgpack/test_seq.py
#   inflating: lambda/pandas/tests/io/msgpack/test_buffer.py
#   inflating: lambda/pandas/tests/io/msgpack/test_unpack_raw.py
#   inflating: lambda/pandas/tests/io/msgpack/test_unpack.py
#   inflating: lambda/pandas/tests/io/msgpack/test_subtype.py
#   inflating: lambda/pandas/tests/io/msgpack/test_sequnpack.py
#   inflating: lambda/pandas/tests/io/msgpack/__init__.py
#   inflating: lambda/pandas/tests/io/msgpack/test_except.py
#   inflating: lambda/pandas/tests/io/msgpack/test_case.py
#   inflating: lambda/pandas/tests/io/sas/test_sas7bdat.py
#   inflating: lambda/pandas/tests/io/sas/test_xport.py
#   inflating: lambda/pandas/tests/io/sas/test_sas.py
#   inflating: lambda/pandas/tests/io/sas/__init__.py
#   inflating: lambda/pandas/tests/io/json/test_pandas.py
#   inflating: lambda/pandas/tests/io/json/test_json_table_schema.py
#   inflating: lambda/pandas/tests/io/json/test_ujson.py
#   inflating: lambda/pandas/tests/io/json/test_compression.py
#   inflating: lambda/pandas/tests/io/json/test_readlines.py
#   inflating: lambda/pandas/tests/io/json/test_normalize.py
#   inflating: lambda/pandas/tests/io/json/__init__.py
#   inflating: lambda/pandas/tests/io/parser/test_na_values.py
#   inflating: lambda/pandas/tests/io/parser/test_usecols.py
#   inflating: lambda/pandas/tests/io/parser/test_c_parser_only.py
#   inflating: lambda/pandas/tests/io/parser/test_parse_dates.py
#   inflating: lambda/pandas/tests/io/parser/test_quoting.py
#   inflating: lambda/pandas/tests/io/parser/test_multi_thread.py
#   inflating: lambda/pandas/tests/io/parser/test_skiprows.py
#   inflating: lambda/pandas/tests/io/parser/test_read_fwf.py
#   inflating: lambda/pandas/tests/io/parser/test_common.py
#   inflating: lambda/pandas/tests/io/parser/test_network.py
#   inflating: lambda/pandas/tests/io/parser/test_compression.py
#   inflating: lambda/pandas/tests/io/parser/test_dtypes.py
#   inflating: lambda/pandas/tests/io/parser/test_mangle_dupes.py
#   inflating: lambda/pandas/tests/io/parser/test_index_col.py
#   inflating: lambda/pandas/tests/io/parser/test_textreader.py
#   inflating: lambda/pandas/tests/io/parser/test_unsupported.py
#   inflating: lambda/pandas/tests/io/parser/test_converters.py
#   inflating: lambda/pandas/tests/io/parser/test_comment.py
#   inflating: lambda/pandas/tests/io/parser/test_header.py
#   inflating: lambda/pandas/tests/io/parser/__init__.py
#   inflating: lambda/pandas/tests/io/parser/test_python_parser_only.py
#   inflating: lambda/pandas/tests/io/parser/conftest.py
#   inflating: lambda/pandas/tests/io/parser/test_dialect.py
#   inflating: lambda/pandas/tests/io/excel/test_readers.py
#   inflating: lambda/pandas/tests/io/excel/test_openpyxl.py
#   inflating: lambda/pandas/tests/io/excel/test_odf.py
#   inflating: lambda/pandas/tests/io/excel/test_xlwt.py
#   inflating: lambda/pandas/tests/io/excel/test_xlsxwriter.py
#   inflating: lambda/pandas/tests/io/excel/test_writers.py
#   inflating: lambda/pandas/tests/io/excel/__init__.py
#   inflating: lambda/pandas/tests/io/excel/test_xlrd.py
#   inflating: lambda/pandas/tests/io/excel/conftest.py
#   inflating: lambda/pandas/tests/io/excel/test_style.py
#   inflating: lambda/pandas/tests/api/test_types.py
#   inflating: lambda/pandas/tests/api/test_api.py
#   inflating: lambda/pandas/tests/api/__init__.py
#   inflating: lambda/pandas/tests/reshape/test_union_categoricals.py
#   inflating: lambda/pandas/tests/reshape/test_reshape.py
#   inflating: lambda/pandas/tests/reshape/test_pivot.py
#   inflating: lambda/pandas/tests/reshape/test_concat.py
#   inflating: lambda/pandas/tests/reshape/test_qcut.py
#   inflating: lambda/pandas/tests/reshape/test_util.py
#   inflating: lambda/pandas/tests/reshape/test_melt.py
#   inflating: lambda/pandas/tests/reshape/test_cut.py
#   inflating: lambda/pandas/tests/reshape/__init__.py
#   inflating: lambda/pandas/tests/reshape/merge/test_join.py
#   inflating: lambda/pandas/tests/reshape/merge/test_merge.py
#   inflating: lambda/pandas/tests/reshape/merge/test_merge_ordered.py
#   inflating: lambda/pandas/tests/reshape/merge/test_merge_asof.py
#   inflating: lambda/pandas/tests/reshape/merge/test_merge_index_as_string.py
#   inflating: lambda/pandas/tests/reshape/merge/__init__.py
#   inflating: lambda/pandas/tests/reshape/merge/test_multi.py
#   inflating: lambda/pandas/tests/indexing/common.py
#   inflating: lambda/pandas/tests/indexing/test_loc.py
#   inflating: lambda/pandas/tests/indexing/test_chaining_and_caching.py
#   inflating: lambda/pandas/tests/indexing/test_coercion.py
#   inflating: lambda/pandas/tests/indexing/test_indexing_slow.py
#   inflating: lambda/pandas/tests/indexing/test_scalar.py
#   inflating: lambda/pandas/tests/indexing/test_iloc.py
#   inflating: lambda/pandas/tests/indexing/test_indexing_engines.py
#   inflating: lambda/pandas/tests/indexing/test_indexing.py
#   inflating: lambda/pandas/tests/indexing/test_partial.py
#   inflating: lambda/pandas/tests/indexing/test_floats.py
#   inflating: lambda/pandas/tests/indexing/test_timedelta.py
#   inflating: lambda/pandas/tests/indexing/test_ix.py
#   inflating: lambda/pandas/tests/indexing/test_datetime.py
#   inflating: lambda/pandas/tests/indexing/__init__.py
#   inflating: lambda/pandas/tests/indexing/test_callable.py
#   inflating: lambda/pandas/tests/indexing/conftest.py
#   inflating: lambda/pandas/tests/indexing/test_categorical.py
#   inflating: lambda/pandas/tests/indexing/multiindex/test_loc.py
#   inflating: lambda/pandas/tests/indexing/multiindex/test_chaining_and_caching.py
#   inflating: lambda/pandas/tests/indexing/multiindex/test_sorted.py
#   inflating: lambda/pandas/tests/indexing/multiindex/test_slice.py
#   inflating: lambda/pandas/tests/indexing/multiindex/test_multiindex.py
#   inflating: lambda/pandas/tests/indexing/multiindex/test_xs.py
#   inflating: lambda/pandas/tests/indexing/multiindex/test_indexing_slow.py
#   inflating: lambda/pandas/tests/indexing/multiindex/test_iloc.py
#   inflating: lambda/pandas/tests/indexing/multiindex/test_partial.py
#   inflating: lambda/pandas/tests/indexing/multiindex/test_set_ops.py
#   inflating: lambda/pandas/tests/indexing/multiindex/test_getitem.py
#   inflating: lambda/pandas/tests/indexing/multiindex/test_ix.py
#   inflating: lambda/pandas/tests/indexing/multiindex/test_datetime.py
#   inflating: lambda/pandas/tests/indexing/multiindex/__init__.py
#   inflating: lambda/pandas/tests/indexing/multiindex/test_setitem.py
#   inflating: lambda/pandas/tests/indexing/multiindex/conftest.py
#   inflating: lambda/pandas/tests/indexing/interval/test_interval.py
#   inflating: lambda/pandas/tests/indexing/interval/__init__.py
#   inflating: lambda/pandas/tests/indexing/interval/test_interval_new.py
#   inflating: lambda/pandas/tests/dtypes/test_inference.py
#   inflating: lambda/pandas/tests/dtypes/test_generic.py
#   inflating: lambda/pandas/tests/dtypes/test_missing.py
#   inflating: lambda/pandas/tests/dtypes/test_concat.py
#   inflating: lambda/pandas/tests/dtypes/test_common.py
#   inflating: lambda/pandas/tests/dtypes/test_dtypes.py
#   inflating: lambda/pandas/tests/dtypes/__init__.py
#   inflating: lambda/pandas/tests/dtypes/cast/test_convert_objects.py
#   inflating: lambda/pandas/tests/dtypes/cast/test_construct_from_scalar.py
#   inflating: lambda/pandas/tests/dtypes/cast/test_downcast.py
#   inflating: lambda/pandas/tests/dtypes/cast/test_find_common_type.py
#   inflating: lambda/pandas/tests/dtypes/cast/test_promote.py
#   inflating: lambda/pandas/tests/dtypes/cast/test_infer_datetimelike.py
#   inflating: lambda/pandas/tests/dtypes/cast/test_infer_dtype.py
#   inflating: lambda/pandas/tests/dtypes/cast/__init__.py
#   inflating: lambda/pandas/tests/dtypes/cast/test_construct_object_arr.py
#   inflating: lambda/pandas/tests/dtypes/cast/test_construct_ndarray.py
#   inflating: lambda/pandas/tests/dtypes/cast/test_upcast.py
#   inflating: lambda/pandas/tests/scalar/test_nat.py
#   inflating: lambda/pandas/tests/scalar/__init__.py
#   inflating: lambda/pandas/tests/scalar/period/test_period.py
#   inflating: lambda/pandas/tests/scalar/period/test_asfreq.py
#   inflating: lambda/pandas/tests/scalar/period/__init__.py
#   inflating: lambda/pandas/tests/scalar/interval/test_ops.py
#   inflating: lambda/pandas/tests/scalar/interval/test_interval.py
#   inflating: lambda/pandas/tests/scalar/interval/__init__.py
#   inflating: lambda/pandas/tests/scalar/timedelta/test_formats.py
#   inflating: lambda/pandas/tests/scalar/timedelta/test_timedelta.py
#   inflating: lambda/pandas/tests/scalar/timedelta/__init__.py
#   inflating: lambda/pandas/tests/scalar/timedelta/test_construction.py
#   inflating: lambda/pandas/tests/scalar/timedelta/test_arithmetic.py
#   inflating: lambda/pandas/tests/scalar/timestamp/test_timezones.py
#   inflating: lambda/pandas/tests/scalar/timestamp/test_unary_ops.py
#   inflating: lambda/pandas/tests/scalar/timestamp/test_comparisons.py
#   inflating: lambda/pandas/tests/scalar/timestamp/test_rendering.py
#   inflating: lambda/pandas/tests/scalar/timestamp/test_timestamp.py
#   inflating: lambda/pandas/tests/scalar/timestamp/__init__.py
#   inflating: lambda/pandas/tests/scalar/timestamp/test_arithmetic.py
#   inflating: lambda/pandas/tests/generic/test_label_or_level_utils.py
#   inflating: lambda/pandas/tests/generic/test_series.py
#   inflating: lambda/pandas/tests/generic/test_generic.py
#   inflating: lambda/pandas/tests/generic/__init__.py
#   inflating: lambda/pandas/tests/generic/test_frame.py
#   inflating: lambda/pandas/tests/plotting/common.py
#   inflating: lambda/pandas/tests/plotting/test_hist_method.py
#   inflating: lambda/pandas/tests/plotting/test_datetimelike.py
#   inflating: lambda/pandas/tests/plotting/test_series.py
#   inflating: lambda/pandas/tests/plotting/test_misc.py
#   inflating: lambda/pandas/tests/plotting/test_groupby.py
#   inflating: lambda/pandas/tests/plotting/test_backend.py
#   inflating: lambda/pandas/tests/plotting/test_boxplot_method.py
#   inflating: lambda/pandas/tests/plotting/__init__.py
#   inflating: lambda/pandas/tests/plotting/test_converter.py
#   inflating: lambda/pandas/tests/plotting/test_frame.py
#   inflating: lambda/pandas/tests/groupby/test_value_counts.py
#   inflating: lambda/pandas/tests/groupby/test_timegrouper.py
#   inflating: lambda/pandas/tests/groupby/test_rank.py
#   inflating: lambda/pandas/tests/groupby/test_bin_groupby.py
#   inflating: lambda/pandas/tests/groupby/test_groupby.py
#   inflating: lambda/pandas/tests/groupby/test_nth.py
#   inflating: lambda/pandas/tests/groupby/test_function.py
#   inflating: lambda/pandas/tests/groupby/test_apply.py
#   inflating: lambda/pandas/tests/groupby/test_whitelist.py
#   inflating: lambda/pandas/tests/groupby/test_filters.py
#   inflating: lambda/pandas/tests/groupby/test_counting.py
#   inflating: lambda/pandas/tests/groupby/test_grouping.py
#   inflating: lambda/pandas/tests/groupby/test_index_as_string.py
#   inflating: lambda/pandas/tests/groupby/__init__.py
#   inflating: lambda/pandas/tests/groupby/test_transform.py
#   inflating: lambda/pandas/tests/groupby/conftest.py
#   inflating: lambda/pandas/tests/groupby/test_categorical.py
#   inflating: lambda/pandas/tests/groupby/aggregate/test_cython.py
#   inflating: lambda/pandas/tests/groupby/aggregate/__init__.py
#   inflating: lambda/pandas/tests/groupby/aggregate/test_aggregate.py
#   inflating: lambda/pandas/tests/groupby/aggregate/test_other.py
#   inflating: lambda/pandas/tests/sparse/common.py
#   inflating: lambda/pandas/tests/sparse/test_reshape.py
#   inflating: lambda/pandas/tests/sparse/test_pivot.py
#   inflating: lambda/pandas/tests/sparse/test_combine_concat.py
#   inflating: lambda/pandas/tests/sparse/test_groupby.py
#   inflating: lambda/pandas/tests/sparse/test_indexing.py
#   inflating: lambda/pandas/tests/sparse/test_format.py
#   inflating: lambda/pandas/tests/sparse/__init__.py
#   inflating: lambda/pandas/tests/sparse/frame/test_analytics.py
#   inflating: lambda/pandas/tests/sparse/frame/test_indexing.py
#   inflating: lambda/pandas/tests/sparse/frame/test_apply.py
#   inflating: lambda/pandas/tests/sparse/frame/test_to_csv.py
#   inflating: lambda/pandas/tests/sparse/frame/__init__.py
#   inflating: lambda/pandas/tests/sparse/frame/test_frame.py
#   inflating: lambda/pandas/tests/sparse/frame/conftest.py
#   inflating: lambda/pandas/tests/sparse/frame/test_to_from_scipy.py
#   inflating: lambda/pandas/tests/sparse/series/test_series.py
#   inflating: lambda/pandas/tests/sparse/series/test_indexing.py
#   inflating: lambda/pandas/tests/sparse/series/__init__.py
#   inflating: lambda/pandas/tests/series/common.py
#   inflating: lambda/pandas/tests/series/test_combine_concat.py
#   inflating: lambda/pandas/tests/series/test_explode.py
#   inflating: lambda/pandas/tests/series/test_duplicates.py
#   inflating: lambda/pandas/tests/series/test_datetime_values.py
#   inflating: lambda/pandas/tests/series/test_rank.py
#   inflating: lambda/pandas/tests/series/test_subclass.py
#   inflating: lambda/pandas/tests/series/test_period.py
#   inflating: lambda/pandas/tests/series/test_replace.py
#   inflating: lambda/pandas/tests/series/test_timezones.py
#   inflating: lambda/pandas/tests/series/test_io.py
#   inflating: lambda/pandas/tests/series/test_internals.py
#   inflating: lambda/pandas/tests/series/test_missing.py
#   inflating: lambda/pandas/tests/series/test_analytics.py
#   inflating: lambda/pandas/tests/series/test_apply.py
#   inflating: lambda/pandas/tests/series/test_constructors.py
#   inflating: lambda/pandas/tests/series/test_dtypes.py
#   inflating: lambda/pandas/tests/series/test_sorting.py
#   inflating: lambda/pandas/tests/series/test_api.py
#   inflating: lambda/pandas/tests/series/test_repr.py
#   inflating: lambda/pandas/tests/series/test_ufunc.py
#   inflating: lambda/pandas/tests/series/test_asof.py
#   inflating: lambda/pandas/tests/series/test_quantile.py
#   inflating: lambda/pandas/tests/series/test_operators.py
#   inflating: lambda/pandas/tests/series/__init__.py
#   inflating: lambda/pandas/tests/series/test_timeseries.py
#   inflating: lambda/pandas/tests/series/test_arithmetic.py
#   inflating: lambda/pandas/tests/series/test_alter_axes.py
#   inflating: lambda/pandas/tests/series/conftest.py
#   inflating: lambda/pandas/tests/series/test_block_internals.py
#   inflating: lambda/pandas/tests/series/test_validate.py
#   inflating: lambda/pandas/tests/series/indexing/test_loc.py
#   inflating: lambda/pandas/tests/series/indexing/test_numeric.py
#   inflating: lambda/pandas/tests/series/indexing/test_iloc.py
#   inflating: lambda/pandas/tests/series/indexing/test_indexing.py
#   inflating: lambda/pandas/tests/series/indexing/test_datetime.py
#   inflating: lambda/pandas/tests/series/indexing/test_boolean.py
#   inflating: lambda/pandas/tests/series/indexing/__init__.py
#   inflating: lambda/pandas/tests/series/indexing/test_alter_index.py
#   inflating: lambda/pandas/tests/series/indexing/test_callable.py
#   inflating: lambda/pandas/tests/series/indexing/conftest.py
#   inflating: lambda/pandas/tests/tools/test_numeric.py
#   inflating: lambda/pandas/tests/tools/__init__.py
#   inflating: lambda/pandas/tests/reductions/test_reductions.py
#   inflating: lambda/pandas/tests/reductions/test_stat_reductions.py
#   inflating: lambda/pandas/tests/reductions/__init__.py
#   inflating: lambda/pandas/tests/util/test_assert_interval_array_equal.py
#   inflating: lambda/pandas/tests/util/test_safe_import.py
#   inflating: lambda/pandas/tests/util/test_assert_numpy_array_equal.py
#   inflating: lambda/pandas/tests/util/test_validate_kwargs.py
#   inflating: lambda/pandas/tests/util/test_hashing.py
#   inflating: lambda/pandas/tests/util/test_deprecate_kwarg.py
#   inflating: lambda/pandas/tests/util/test_move.py
#   inflating: lambda/pandas/tests/util/test_assert_extension_array_equal.py
#   inflating: lambda/pandas/tests/util/test_assert_categorical_equal.py
#   inflating: lambda/pandas/tests/util/test_util.py
#   inflating: lambda/pandas/tests/util/test_deprecate.py
#   inflating: lambda/pandas/tests/util/test_validate_args.py
#   inflating: lambda/pandas/tests/util/test_assert_almost_equal.py
#   inflating: lambda/pandas/tests/util/test_assert_produces_warning.py
#   inflating: lambda/pandas/tests/util/test_assert_frame_equal.py
#   inflating: lambda/pandas/tests/util/test_assert_series_equal.py
#   inflating: lambda/pandas/tests/util/__init__.py
#   inflating: lambda/pandas/tests/util/conftest.py
#   inflating: lambda/pandas/tests/util/test_assert_index_equal.py
#   inflating: lambda/pandas/tests/util/test_validate_args_and_kwargs.py
#   inflating: lambda/pandas/tests/extension/test_numpy.py
#   inflating: lambda/pandas/tests/extension/test_period.py
#   inflating: lambda/pandas/tests/extension/test_integer.py
#   inflating: lambda/pandas/tests/extension/test_sparse.py
#   inflating: lambda/pandas/tests/extension/test_common.py
#   inflating: lambda/pandas/tests/extension/test_external_block.py
#   inflating: lambda/pandas/tests/extension/test_interval.py
#   inflating: lambda/pandas/tests/extension/test_datetime.py
#   inflating: lambda/pandas/tests/extension/__init__.py
#   inflating: lambda/pandas/tests/extension/conftest.py
#   inflating: lambda/pandas/tests/extension/test_categorical.py
#   inflating: lambda/pandas/tests/extension/base/interface.py
#   inflating: lambda/pandas/tests/extension/base/reshaping.py
#   inflating: lambda/pandas/tests/extension/base/methods.py
#   inflating: lambda/pandas/tests/extension/base/getitem.py
#   inflating: lambda/pandas/tests/extension/base/casting.py
#   inflating: lambda/pandas/tests/extension/base/dtype.py
#   inflating: lambda/pandas/tests/extension/base/setitem.py
#   inflating: lambda/pandas/tests/extension/base/missing.py
#   inflating: lambda/pandas/tests/extension/base/__init__.py
#   inflating: lambda/pandas/tests/extension/base/groupby.py
#   inflating: lambda/pandas/tests/extension/base/printing.py
#   inflating: lambda/pandas/tests/extension/base/constructors.py
#   inflating: lambda/pandas/tests/extension/base/ops.py
#   inflating: lambda/pandas/tests/extension/base/io.py
#   inflating: lambda/pandas/tests/extension/base/reduce.py
#   inflating: lambda/pandas/tests/extension/base/base.py
#   inflating: lambda/pandas/tests/extension/decimal/test_decimal.py
#   inflating: lambda/pandas/tests/extension/decimal/array.py
#   inflating: lambda/pandas/tests/extension/decimal/__init__.py
#   inflating: lambda/pandas/tests/extension/arrow/bool.py
#   inflating: lambda/pandas/tests/extension/arrow/test_bool.py
#   inflating: lambda/pandas/tests/extension/arrow/__init__.py
#   inflating: lambda/pandas/tests/extension/json/test_json.py
#   inflating: lambda/pandas/tests/extension/json/array.py
#   inflating: lambda/pandas/tests/extension/json/__init__.py
#   inflating: lambda/pandas/tests/extension/list/test_list.py
#   inflating: lambda/pandas/tests/extension/list/array.py
#   inflating: lambda/pandas/tests/extension/list/__init__.py
#   inflating: lambda/pandas/tests/arrays/test_numpy.py
#   inflating: lambda/pandas/tests/arrays/test_datetimelike.py
#   inflating: lambda/pandas/tests/arrays/test_timedeltas.py
#   inflating: lambda/pandas/tests/arrays/test_period.py
#   inflating: lambda/pandas/tests/arrays/test_array.py
#   inflating: lambda/pandas/tests/arrays/test_integer.py
#   inflating: lambda/pandas/tests/arrays/__init__.py
#   inflating: lambda/pandas/tests/arrays/test_datetimes.py
#   inflating: lambda/pandas/tests/arrays/categorical/common.py
#   inflating: lambda/pandas/tests/arrays/categorical/test_subclass.py
#   inflating: lambda/pandas/tests/arrays/categorical/test_missing.py
#   inflating: lambda/pandas/tests/arrays/categorical/test_analytics.py
#   inflating: lambda/pandas/tests/arrays/categorical/test_indexing.py
#   inflating: lambda/pandas/tests/arrays/categorical/test_constructors.py
#   inflating: lambda/pandas/tests/arrays/categorical/test_algos.py
#   inflating: lambda/pandas/tests/arrays/categorical/test_dtypes.py
#   inflating: lambda/pandas/tests/arrays/categorical/test_sorting.py
#   inflating: lambda/pandas/tests/arrays/categorical/test_api.py
#   inflating: lambda/pandas/tests/arrays/categorical/test_repr.py
#   inflating: lambda/pandas/tests/arrays/categorical/test_warnings.py
#   inflating: lambda/pandas/tests/arrays/categorical/test_operators.py
#   inflating: lambda/pandas/tests/arrays/categorical/__init__.py
#   inflating: lambda/pandas/tests/arrays/categorical/conftest.py
#   inflating: lambda/pandas/tests/arrays/interval/test_ops.py
#   inflating: lambda/pandas/tests/arrays/interval/test_interval.py
#   inflating: lambda/pandas/tests/arrays/interval/__init__.py
#   inflating: lambda/pandas/tests/arrays/sparse/test_dtype.py
#   inflating: lambda/pandas/tests/arrays/sparse/test_libsparse.py
#   inflating: lambda/pandas/tests/arrays/sparse/test_array.py
#   inflating: lambda/pandas/tests/arrays/sparse/__init__.py
#   inflating: lambda/pandas/tests/arrays/sparse/test_arithmetics.py
#   inflating: lambda/pandas/tests/arrays/sparse/test_accessor.py
#   inflating: lambda/pandas/tests/internals/test_internals.py
#   inflating: lambda/pandas/tests/internals/__init__.py
#   inflating: lambda/pandas/io/common.py
#   inflating: lambda/pandas/io/pytables.py
#   inflating: lambda/pandas/io/s3.py
#   inflating: lambda/pandas/io/pickle.py
#   inflating: lambda/pandas/io/feather_format.py
#   inflating: lambda/pandas/io/sql.py
#   inflating: lambda/pandas/io/packers.py
#   inflating: lambda/pandas/io/spss.py
#   inflating: lambda/pandas/io/gcs.py
#   inflating: lambda/pandas/io/clipboards.py
#   inflating: lambda/pandas/io/gbq.py
#   inflating: lambda/pandas/io/stata.py
#   inflating: lambda/pandas/io/api.py
#   inflating: lambda/pandas/io/__init__.py
#   inflating: lambda/pandas/io/parquet.py
#   inflating: lambda/pandas/io/html.py
#   inflating: lambda/pandas/io/parsers.py
#   inflating: lambda/pandas/io/date_converters.py
#   inflating: lambda/pandas/io/formats/latex.py
#   inflating: lambda/pandas/io/formats/css.py
#   inflating: lambda/pandas/io/formats/style.py
#   inflating: lambda/pandas/io/formats/excel.py
#   inflating: lambda/pandas/io/formats/format.py
#   inflating: lambda/pandas/io/formats/console.py
#   inflating: lambda/pandas/io/formats/csvs.py
#   inflating: lambda/pandas/io/formats/__init__.py
#   inflating: lambda/pandas/io/formats/printing.py
#   inflating: lambda/pandas/io/formats/html.py
#   inflating: lambda/pandas/io/formats/templates/html.tpl
#   inflating: lambda/pandas/io/msgpack/exceptions.py
#   inflating: lambda/pandas/io/msgpack/_packer.cpython-38-x86_64-linux-gnu.so
#   inflating: lambda/pandas/io/msgpack/_unpacker.cpython-38-x86_64-linux-gnu.so
#   inflating: lambda/pandas/io/msgpack/_version.py
#   inflating: lambda/pandas/io/msgpack/__init__.py
#   inflating: lambda/pandas/io/sas/sas7bdat.py
#   inflating: lambda/pandas/io/sas/sas_xport.py
#   inflating: lambda/pandas/io/sas/sas_constants.py
#   inflating: lambda/pandas/io/sas/_sas.cpython-38-x86_64-linux-gnu.so
#   inflating: lambda/pandas/io/sas/__init__.py
#   inflating: lambda/pandas/io/sas/sasreader.py
#   inflating: lambda/pandas/io/json/_json.py
#   inflating: lambda/pandas/io/json/_table_schema.py
#   inflating: lambda/pandas/io/json/_normalize.py
#   inflating: lambda/pandas/io/json/__init__.py
#   inflating: lambda/pandas/io/clipboard/exceptions.py
#   inflating: lambda/pandas/io/clipboard/clipboards.py
#   inflating: lambda/pandas/io/clipboard/__init__.py
#   inflating: lambda/pandas/io/clipboard/windows.py
#   inflating: lambda/pandas/io/excel/_odfreader.py
#   inflating: lambda/pandas/io/excel/_xlsxwriter.py
#   inflating: lambda/pandas/io/excel/_openpyxl.py
#   inflating: lambda/pandas/io/excel/_xlwt.py
#   inflating: lambda/pandas/io/excel/_xlrd.py
#   inflating: lambda/pandas/io/excel/__init__.py
#   inflating: lambda/pandas/io/excel/_base.py
#   inflating: lambda/pandas/io/excel/_util.py
#   inflating: lambda/pandas/_config/localization.py
#   inflating: lambda/pandas/_config/config.py
#   inflating: lambda/pandas/_config/display.py
#   inflating: lambda/pandas/_config/__init__.py
#   inflating: lambda/pandas/_config/dates.py
#   inflating: lambda/pandas/compat/_optional.py
#   inflating: lambda/pandas/compat/pickle_compat.py
#   inflating: lambda/pandas/compat/__init__.py
#   inflating: lambda/pandas/compat/chainmap.py
#   inflating: lambda/pandas/compat/numpy/function.py
#   inflating: lambda/pandas/compat/numpy/__init__.py
#   inflating: lambda/pandas/api/__init__.py
#   inflating: lambda/pandas/api/extensions/__init__.py
#   inflating: lambda/pandas/api/types/__init__.py
#   inflating: lambda/pandas/core/common.py
#   inflating: lambda/pandas/core/nanops.py
#   inflating: lambda/pandas/core/accessor.py
#   inflating: lambda/pandas/core/window.py
#   inflating: lambda/pandas/core/generic.py
#   inflating: lambda/pandas/core/sorting.py
#   inflating: lambda/pandas/core/algorithms.py
#   inflating: lambda/pandas/core/indexing.py
#   inflating: lambda/pandas/core/indexers.py
#   inflating: lambda/pandas/core/config_init.py
#   inflating: lambda/pandas/core/apply.py
#   inflating: lambda/pandas/core/strings.py
#   inflating: lambda/pandas/core/frame.py
#   inflating: lambda/pandas/core/api.py
#   inflating: lambda/pandas/core/missing.py
#   inflating: lambda/pandas/core/series.py
#   inflating: lambda/pandas/core/__init__.py
#   inflating: lambda/pandas/core/resample.py
#   inflating: lambda/pandas/core/index.py
#   inflating: lambda/pandas/core/base.py
#   inflating: lambda/pandas/core/computation/common.py
#   inflating: lambda/pandas/core/computation/pytables.py
#   inflating: lambda/pandas/core/computation/check.py
#   inflating: lambda/pandas/core/computation/expressions.py
#   inflating: lambda/pandas/core/computation/engines.py
#   inflating: lambda/pandas/core/computation/align.py
#   inflating: lambda/pandas/core/computation/expr.py
#   inflating: lambda/pandas/core/computation/eval.py
#   inflating: lambda/pandas/core/computation/api.py
#   inflating: lambda/pandas/core/computation/scope.py
#   inflating: lambda/pandas/core/computation/__init__.py
#   inflating: lambda/pandas/core/computation/ops.py
#   inflating: lambda/pandas/core/ops/docstrings.py
#   inflating: lambda/pandas/core/ops/roperator.py
#   inflating: lambda/pandas/core/ops/missing.py
#   inflating: lambda/pandas/core/ops/__init__.py
#   inflating: lambda/pandas/core/indexes/datetimelike.py
#   inflating: lambda/pandas/core/indexes/range.py
#   inflating: lambda/pandas/core/indexes/timedeltas.py
#   inflating: lambda/pandas/core/indexes/period.py
#   inflating: lambda/pandas/core/indexes/accessors.py
#   inflating: lambda/pandas/core/indexes/category.py
#   inflating: lambda/pandas/core/indexes/numeric.py
#   inflating: lambda/pandas/core/indexes/multi.py
#   inflating: lambda/pandas/core/indexes/api.py
#   inflating: lambda/pandas/core/indexes/interval.py
#   inflating: lambda/pandas/core/indexes/frozen.py
#   inflating: lambda/pandas/core/indexes/__init__.py
#   inflating: lambda/pandas/core/indexes/base.py
#   inflating: lambda/pandas/core/indexes/datetimes.py
#   inflating: lambda/pandas/core/reshape/concat.py
#   inflating: lambda/pandas/core/reshape/reshape.py
#   inflating: lambda/pandas/core/reshape/tile.py
#   inflating: lambda/pandas/core/reshape/api.py
#   inflating: lambda/pandas/core/reshape/__init__.py
#   inflating: lambda/pandas/core/reshape/pivot.py
#   inflating: lambda/pandas/core/reshape/merge.py
#   inflating: lambda/pandas/core/reshape/melt.py
#   inflating: lambda/pandas/core/reshape/util.py
#   inflating: lambda/pandas/core/dtypes/common.py
#   inflating: lambda/pandas/core/dtypes/concat.py
#   inflating: lambda/pandas/core/dtypes/inference.py
#   inflating: lambda/pandas/core/dtypes/dtypes.py
#   inflating: lambda/pandas/core/dtypes/generic.py
#   inflating: lambda/pandas/core/dtypes/api.py
#   inflating: lambda/pandas/core/dtypes/missing.py
#   inflating: lambda/pandas/core/dtypes/__init__.py
#   inflating: lambda/pandas/core/dtypes/cast.py
#   inflating: lambda/pandas/core/dtypes/base.py
#   inflating: lambda/pandas/core/groupby/categorical.py
#   inflating: lambda/pandas/core/groupby/generic.py
#   inflating: lambda/pandas/core/groupby/grouper.py
#   inflating: lambda/pandas/core/groupby/__init__.py
#   inflating: lambda/pandas/core/groupby/groupby.py
#   inflating: lambda/pandas/core/groupby/ops.py
#   inflating: lambda/pandas/core/groupby/base.py
#   inflating: lambda/pandas/core/sparse/frame.py
#   inflating: lambda/pandas/core/sparse/scipy_sparse.py
#   inflating: lambda/pandas/core/sparse/api.py
#   inflating: lambda/pandas/core/sparse/series.py
#   inflating: lambda/pandas/core/sparse/__init__.py
#   inflating: lambda/pandas/core/tools/timedeltas.py
#   inflating: lambda/pandas/core/tools/numeric.py
#   inflating: lambda/pandas/core/tools/__init__.py
#   inflating: lambda/pandas/core/tools/datetimes.py
#   inflating: lambda/pandas/core/util/hashing.py
#   inflating: lambda/pandas/core/util/__init__.py
#   inflating: lambda/pandas/core/arrays/sparse.py
#   inflating: lambda/pandas/core/arrays/datetimelike.py
#   inflating: lambda/pandas/core/arrays/integer.py
#   inflating: lambda/pandas/core/arrays/categorical.py
#   inflating: lambda/pandas/core/arrays/timedeltas.py
#   inflating: lambda/pandas/core/arrays/period.py
#   inflating: lambda/pandas/core/arrays/_ranges.py
#   inflating: lambda/pandas/core/arrays/array_.py
#   inflating: lambda/pandas/core/arrays/numpy_.py
#   inflating: lambda/pandas/core/arrays/interval.py
#   inflating: lambda/pandas/core/arrays/__init__.py
#   inflating: lambda/pandas/core/arrays/base.py
#   inflating: lambda/pandas/core/arrays/datetimes.py
#   inflating: lambda/pandas/core/internals/concat.py
#   inflating: lambda/pandas/core/internals/blocks.py
#   inflating: lambda/pandas/core/internals/construction.py
#   inflating: lambda/pandas/core/internals/arrays.py
#   inflating: lambda/pandas/core/internals/__init__.py
#   inflating: lambda/pandas/core/internals/managers.py
#   inflating: lambda/pandas/errors/__init__.py
#   inflating: lambda/pandas/plotting/_misc.py
#   inflating: lambda/pandas/plotting/__init__.py
#   inflating: lambda/pandas/plotting/_core.py
#   inflating: lambda/pandas/plotting/_matplotlib/core.py
#   inflating: lambda/pandas/plotting/_matplotlib/style.py
#   inflating: lambda/pandas/plotting/_matplotlib/boxplot.py
#   inflating: lambda/pandas/plotting/_matplotlib/timeseries.py
#   inflating: lambda/pandas/plotting/_matplotlib/converter.py
#   inflating: lambda/pandas/plotting/_matplotlib/hist.py
#   inflating: lambda/pandas/plotting/_matplotlib/compat.py
#   inflating: lambda/pandas/plotting/_matplotlib/tools.py
#   inflating: lambda/pandas/plotting/_matplotlib/__init__.py
#   inflating: lambda/pandas/plotting/_matplotlib/misc.py
#   inflating: lambda/pandas/_libs/hashtable.cpython-38-x86_64-linux-gnu.so
#   inflating: lambda/pandas/_libs/parsers.cpython-38-x86_64-linux-gnu.so
#   inflating: lambda/pandas/_libs/hashing.cpython-38-x86_64-linux-gnu.so
#   inflating: lambda/pandas/_libs/writers.cpython-38-x86_64-linux-gnu.so
#   inflating: lambda/pandas/_libs/json.cpython-38-x86_64-linux-gnu.so
#   inflating: lambda/pandas/_libs/join.cpython-38-x86_64-linux-gnu.so
#   inflating: lambda/pandas/_libs/skiplist.cpython-38-x86_64-linux-gnu.so
# ...
#   inflating: lambda/numpy/core/include/numpy/oldnumeric.h
#   inflating: lambda/numpy/core/include/numpy/utils.h
#   inflating: lambda/numpy/core/include/numpy/npy_math.h
#   inflating: lambda/numpy/core/include/numpy/__multiarray_api.h
#   inflating: lambda/numpy/core/include/numpy/multiarray_api.txt
#   inflating: lambda/numpy/core/include/numpy/npy_endian.h
#   inflating: lambda/numpy/core/include/numpy/arrayobject.h
#   inflating: lambda/numpy/core/include/numpy/ufuncobject.h
#   inflating: lambda/numpy/core/include/numpy/_numpyconfig.h
#   inflating: lambda/numpy/core/include/numpy/npy_cpu.h
#   inflating: lambda/numpy/core/include/numpy/halffloat.h
#   inflating: lambda/numpy/core/include/numpy/random/bitgen.h
#   inflating: lambda/numpy/core/tests/test_scalarbuffer.py
#   inflating: lambda/numpy/core/tests/test_shape_base.py
#   inflating: lambda/numpy/core/tests/test_umath.py
#   inflating: lambda/numpy/core/tests/test_datetime.py
#   inflating: lambda/numpy/core/tests/test_machar.py
#   inflating: lambda/numpy/core/tests/test_scalarprint.py
#   inflating: lambda/numpy/core/tests/test_einsum.py
#   inflating: lambda/numpy/core/tests/test_extint128.py
#   inflating: lambda/numpy/core/tests/test_function_base.py
#   inflating: lambda/numpy/core/tests/test_numerictypes.py
#   inflating: lambda/numpy/core/tests/test_numeric.py
#   inflating: lambda/numpy/core/tests/test_memmap.py
#   inflating: lambda/numpy/core/tests/test_scalarmath.py
#   inflating: lambda/numpy/core/tests/test_umath_accuracy.py
#   inflating: lambda/numpy/core/tests/_locales.py
#   inflating: lambda/numpy/core/tests/test_overrides.py
#   inflating: lambda/numpy/core/tests/test_mem_overlap.py
#   inflating: lambda/numpy/core/tests/test_dtype.py
#   inflating: lambda/numpy/core/tests/test_arrayprint.py
#   inflating: lambda/numpy/core/tests/test_half.py
#   inflating: lambda/numpy/core/tests/__init__.py
#   inflating: lambda/numpy/core/tests/test_multiarray.py
#   inflating: lambda/numpy/core/tests/test_getlimits.py
#   inflating: lambda/numpy/core/tests/test_indexing.py
#   inflating: lambda/numpy/core/tests/test_errstate.py
#   inflating: lambda/numpy/core/tests/test_unicode.py
#   inflating: lambda/numpy/core/tests/test_abc.py
#   inflating: lambda/numpy/core/tests/test_print.py
#   inflating: lambda/numpy/core/tests/test_scalarinherit.py
#   inflating: lambda/numpy/core/tests/test_api.py
#   inflating: lambda/numpy/core/tests/test_ufunc.py
#   inflating: lambda/numpy/core/tests/test_umath_complex.py
#   inflating: lambda/numpy/core/tests/test_scalar_methods.py
#   inflating: lambda/numpy/core/tests/test_defchararray.py
#   inflating: lambda/numpy/core/tests/test_scalar_ctors.py
#   inflating: lambda/numpy/core/tests/test_longdouble.py
#   inflating: lambda/numpy/core/tests/test_item_selection.py
#   inflating: lambda/numpy/core/tests/test_regression.py
#   inflating: lambda/numpy/core/tests/test_deprecations.py
#   inflating: lambda/numpy/core/tests/test_nditer.py
#   inflating: lambda/numpy/core/tests/test_records.py
#   inflating: lambda/numpy/core/tests/test_indexerrors.py
#   inflating: lambda/numpy/core/tests/data/umath-validation-set-README
#   inflating: lambda/numpy/core/tests/data/astype_copy.pkl
#   inflating: lambda/numpy/core/tests/data/umath-validation-set-sin
#   inflating: lambda/numpy/core/tests/data/umath-validation-set-cos
#   inflating: lambda/numpy/core/tests/data/umath-validation-set-log
#   inflating: lambda/numpy/core/tests/data/umath-validation-set-exp
#   inflating: lambda/numpy/core/tests/data/recarray_from_file.fits
#   inflating: lambda/numpy/core/lib/libnpymath.a
#   inflating: lambda/numpy/core/lib/npy-pkg-config/mlib.ini
#   inflating: lambda/numpy/core/lib/npy-pkg-config/npymath.ini
#   inflating: lambda/numpy/lib/_iotools.py
#   inflating: lambda/numpy/lib/type_check.py
#   inflating: lambda/numpy/lib/mixins.py
#   inflating: lambda/numpy/lib/info.py
#   inflating: lambda/numpy/lib/setup.py
#   inflating: lambda/numpy/lib/arraypad.py
#   inflating: lambda/numpy/lib/scimath.py
#   inflating: lambda/numpy/lib/user_array.py
#   inflating: lambda/numpy/lib/ufunclike.py
#   inflating: lambda/numpy/lib/_datasource.py
#   inflating: lambda/numpy/lib/__init__.py
#   inflating: lambda/numpy/lib/format.py
#   inflating: lambda/numpy/lib/recfunctions.py
#   inflating: lambda/numpy/lib/shape_base.py
#   inflating: lambda/numpy/lib/index_tricks.py
#   inflating: lambda/numpy/lib/npyio.py
#   inflating: lambda/numpy/lib/arraysetops.py
#   inflating: lambda/numpy/lib/arrayterator.py
#   inflating: lambda/numpy/lib/histograms.py
#   inflating: lambda/numpy/lib/nanfunctions.py
#   inflating: lambda/numpy/lib/_version.py
#   inflating: lambda/numpy/lib/utils.py
#   inflating: lambda/numpy/lib/function_base.py
#   inflating: lambda/numpy/lib/stride_tricks.py
#   inflating: lambda/numpy/lib/twodim_base.py
#   inflating: lambda/numpy/lib/financial.py
#   inflating: lambda/numpy/lib/polynomial.py
#   inflating: lambda/numpy/lib/tests/test_shape_base.py
#   inflating: lambda/numpy/lib/tests/test_recfunctions.py
#   inflating: lambda/numpy/lib/tests/test_type_check.py
#   inflating: lambda/numpy/lib/tests/test_arrayterator.py
#   inflating: lambda/numpy/lib/tests/test_polynomial.py
#   inflating: lambda/numpy/lib/tests/test_function_base.py
#   inflating: lambda/numpy/lib/tests/test_stride_tricks.py
#   inflating: lambda/numpy/lib/tests/test_ufunclike.py
#   inflating: lambda/numpy/lib/tests/test_histograms.py
#   inflating: lambda/numpy/lib/tests/test_arraysetops.py
#   inflating: lambda/numpy/lib/tests/test_format.py
#   inflating: lambda/numpy/lib/tests/test_index_tricks.py
#   inflating: lambda/numpy/lib/tests/test_io.py
#   inflating: lambda/numpy/lib/tests/test__iotools.py
#   inflating: lambda/numpy/lib/tests/__init__.py
#   inflating: lambda/numpy/lib/tests/test_utils.py
#   inflating: lambda/numpy/lib/tests/test_financial.py
#   inflating: lambda/numpy/lib/tests/test_twodim_base.py
#   inflating: lambda/numpy/lib/tests/test__version.py
#   inflating: lambda/numpy/lib/tests/test_arraypad.py
#   inflating: lambda/numpy/lib/tests/test_nanfunctions.py
#   inflating: lambda/numpy/lib/tests/test_mixins.py
#   inflating: lambda/numpy/lib/tests/test_regression.py
#   inflating: lambda/numpy/lib/tests/test__datasource.py
#   inflating: lambda/numpy/lib/tests/test_packbits.py
#   inflating: lambda/numpy/lib/tests/data/py3-objarr.npy
#   inflating: lambda/numpy/lib/tests/data/py2-objarr.npy
#   inflating: lambda/numpy/lib/tests/data/win64python2.npy
#   inflating: lambda/numpy/lib/tests/data/py2-objarr.npz
#   inflating: lambda/numpy/lib/tests/data/python3.npy
#   inflating: lambda/numpy/lib/tests/data/py3-objarr.npz
#   inflating: lambda/numpy/distutils/conv_template.py
#   inflating: lambda/numpy/distutils/system_info.py
#   inflating: lambda/numpy/distutils/msvc9compiler.py
#   inflating: lambda/numpy/distutils/info.py
#   inflating: lambda/numpy/distutils/setup.py
#   inflating: lambda/numpy/distutils/log.py
#   inflating: lambda/numpy/distutils/extension.py
#   inflating: lambda/numpy/distutils/ccompiler.py
#   inflating: lambda/numpy/distutils/line_endings.py
#   inflating: lambda/numpy/distutils/npy_pkg_config.py
#   inflating: lambda/numpy/distutils/__config__.py
#   inflating: lambda/numpy/distutils/intelccompiler.py
#   inflating: lambda/numpy/distutils/__init__.py
#   inflating: lambda/numpy/distutils/msvccompiler.py
#   inflating: lambda/numpy/distutils/exec_command.py
#   inflating: lambda/numpy/distutils/pathccompiler.py
#   inflating: lambda/numpy/distutils/mingw32ccompiler.py
#   inflating: lambda/numpy/distutils/__version__.py
#   inflating: lambda/numpy/distutils/from_template.py
#   inflating: lambda/numpy/distutils/core.py
#   inflating: lambda/numpy/distutils/cpuinfo.py
#   inflating: lambda/numpy/distutils/lib2def.py
#   inflating: lambda/numpy/distutils/misc_util.py
#   inflating: lambda/numpy/distutils/unixccompiler.py
#   inflating: lambda/numpy/distutils/_shell_utils.py
#   inflating: lambda/numpy/distutils/numpy_distribution.py
#   inflating: lambda/numpy/distutils/compat.py
#   inflating: lambda/numpy/distutils/tests/test_fcompiler.py
#   inflating: lambda/numpy/distutils/tests/__init__.py
#   inflating: lambda/numpy/distutils/tests/test_from_template.py
#   inflating: lambda/numpy/distutils/tests/test_npy_pkg_config.py
#   inflating: lambda/numpy/distutils/tests/test_fcompiler_nagfor.py
#   inflating: lambda/numpy/distutils/tests/test_shell_utils.py
#   inflating: lambda/numpy/distutils/tests/test_system_info.py
#   inflating: lambda/numpy/distutils/tests/test_fcompiler_intel.py
#   inflating: lambda/numpy/distutils/tests/test_fcompiler_gnu.py
#   inflating: lambda/numpy/distutils/tests/test_misc_util.py
#   inflating: lambda/numpy/distutils/tests/test_exec_command.py
#   inflating: lambda/numpy/distutils/command/egg_info.py
#   inflating: lambda/numpy/distutils/command/install_headers.py
#   inflating: lambda/numpy/distutils/command/build_py.py
#   inflating: lambda/numpy/distutils/command/build_ext.py
#   inflating: lambda/numpy/distutils/command/build.py
#   inflating: lambda/numpy/distutils/command/config_compiler.py
#   inflating: lambda/numpy/distutils/command/__init__.py
#   inflating: lambda/numpy/distutils/command/bdist_rpm.py
#   inflating: lambda/numpy/distutils/command/config.py
#   inflating: lambda/numpy/distutils/command/build_src.py
#   inflating: lambda/numpy/distutils/command/build_scripts.py
#   inflating: lambda/numpy/distutils/command/sdist.py
#   inflating: lambda/numpy/distutils/command/install_data.py
#   inflating: lambda/numpy/distutils/command/install.py
#   inflating: lambda/numpy/distutils/command/build_clib.py
#   inflating: lambda/numpy/distutils/command/develop.py
#   inflating: lambda/numpy/distutils/command/autodist.py
#   inflating: lambda/numpy/distutils/command/install_clib.py
#   inflating: lambda/numpy/distutils/mingw/gfortran_vs2003_hack.c
#   inflating: lambda/numpy/distutils/fcompiler/lahey.py
#   inflating: lambda/numpy/distutils/fcompiler/nag.py
#   inflating: lambda/numpy/distutils/fcompiler/g95.py
#   inflating: lambda/numpy/distutils/fcompiler/none.py
#   inflating: lambda/numpy/distutils/fcompiler/pathf95.py
#   inflating: lambda/numpy/distutils/fcompiler/__init__.py
#   inflating: lambda/numpy/distutils/fcompiler/compaq.py
#   inflating: lambda/numpy/distutils/fcompiler/ibm.py
#   inflating: lambda/numpy/distutils/fcompiler/hpux.py
#   inflating: lambda/numpy/distutils/fcompiler/vast.py
#   inflating: lambda/numpy/distutils/fcompiler/environment.py
#   inflating: lambda/numpy/distutils/fcompiler/mips.py
#   inflating: lambda/numpy/distutils/fcompiler/sun.py
#   inflating: lambda/numpy/distutils/fcompiler/gnu.py
#   inflating: lambda/numpy/distutils/fcompiler/pg.py
#   inflating: lambda/numpy/distutils/fcompiler/intel.py
#   inflating: lambda/numpy/distutils/fcompiler/absoft.py
#   inflating: lambda/numpy/compat/setup.py
#   inflating: lambda/numpy/compat/__init__.py
#   inflating: lambda/numpy/compat/py3k.py
#   inflating: lambda/numpy/compat/_inspect.py
#   inflating: lambda/numpy/compat/tests/test_compat.py
#   inflating: lambda/numpy/compat/tests/__init__.py
#   inflating: lambda/numpy/f2py/capi_maps.py
#   inflating: lambda/numpy/f2py/info.py
#   inflating: lambda/numpy/f2py/setup.py
#   inflating: lambda/numpy/f2py/diagnose.py
#   inflating: lambda/numpy/f2py/cfuncs.py
#   inflating: lambda/numpy/f2py/cb_rules.py
#   inflating: lambda/numpy/f2py/__main__.py
#   inflating: lambda/numpy/f2py/__init__.py
#   inflating: lambda/numpy/f2py/common_rules.py
#   inflating: lambda/numpy/f2py/f2py2e.py
#   inflating: lambda/numpy/f2py/__version__.py
#   inflating: lambda/numpy/f2py/auxfuncs.py
#   inflating: lambda/numpy/f2py/func2subr.py
#   inflating: lambda/numpy/f2py/crackfortran.py
#   inflating: lambda/numpy/f2py/f90mod_rules.py
#   inflating: lambda/numpy/f2py/f2py_testing.py
#   inflating: lambda/numpy/f2py/rules.py
#   inflating: lambda/numpy/f2py/use_rules.py
#   inflating: lambda/numpy/f2py/tests/test_size.py
#   inflating: lambda/numpy/f2py/tests/test_return_integer.py
#   inflating: lambda/numpy/f2py/tests/test_string.py
#   inflating: lambda/numpy/f2py/tests/test_return_logical.py
#   inflating: lambda/numpy/f2py/tests/test_array_from_pyobj.py
#   inflating: lambda/numpy/f2py/tests/test_return_complex.py
#   inflating: lambda/numpy/f2py/tests/test_assumed_shape.py
#   inflating: lambda/numpy/f2py/tests/test_quoted_character.py
#   inflating: lambda/numpy/f2py/tests/test_return_character.py
#   inflating: lambda/numpy/f2py/tests/__init__.py
#   inflating: lambda/numpy/f2py/tests/test_common.py
#   inflating: lambda/numpy/f2py/tests/test_mixed.py
#   inflating: lambda/numpy/f2py/tests/test_return_real.py
#   inflating: lambda/numpy/f2py/tests/test_callback.py
#   inflating: lambda/numpy/f2py/tests/util.py
#   inflating: lambda/numpy/f2py/tests/test_parameter.py
#   inflating: lambda/numpy/f2py/tests/test_block_docstring.py
#   inflating: lambda/numpy/f2py/tests/test_regression.py
#   inflating: lambda/numpy/f2py/tests/test_compile_function.py
#   inflating: lambda/numpy/f2py/tests/test_semicolon_split.py
#   inflating: lambda/numpy/f2py/tests/test_kind.py
#   inflating: lambda/numpy/f2py/tests/src/common/block.f
#   inflating: lambda/numpy/f2py/tests/src/regression/inout.f90
#   inflating: lambda/numpy/f2py/tests/src/size/foo.f90
#   inflating: lambda/numpy/f2py/tests/src/string/char.f90
#   inflating: lambda/numpy/f2py/tests/src/parameter/constant_compound.f90
#   inflating: lambda/numpy/f2py/tests/src/parameter/constant_both.f90
#   inflating: lambda/numpy/f2py/tests/src/parameter/constant_integer.f90
#   inflating: lambda/numpy/f2py/tests/src/parameter/constant_real.f90
#   inflating: lambda/numpy/f2py/tests/src/parameter/constant_non_compound.f90
#   inflating: lambda/numpy/f2py/tests/src/mixed/foo_fixed.f90
#   inflating: lambda/numpy/f2py/tests/src/mixed/foo.f
#   inflating: lambda/numpy/f2py/tests/src/mixed/foo_free.f90
#   inflating: lambda/numpy/f2py/tests/src/array_from_pyobj/wrapmodule.c
#   inflating: lambda/numpy/f2py/tests/src/assumed_shape/foo_use.f90
#   inflating: lambda/numpy/f2py/tests/src/assumed_shape/precision.f90
#   inflating: lambda/numpy/f2py/tests/src/assumed_shape/.f2py_f2cmap
#   inflating: lambda/numpy/f2py/tests/src/assumed_shape/foo_mod.f90
#   inflating: lambda/numpy/f2py/tests/src/assumed_shape/foo_free.f90
#   inflating: lambda/numpy/f2py/tests/src/kind/foo.f90
#   inflating: lambda/numpy/f2py/src/fortranobject.c
#   inflating: lambda/numpy/f2py/src/fortranobject.h
#   inflating: lambda/numpy/testing/setup.py
#   inflating: lambda/numpy/testing/decorators.py
#   inflating: lambda/numpy/testing/noseclasses.py
#   inflating: lambda/numpy/testing/__init__.py
#   inflating: lambda/numpy/testing/print_coercion_tables.py
#   inflating: lambda/numpy/testing/utils.py
#   inflating: lambda/numpy/testing/nosetester.py
#   inflating: lambda/numpy/testing/_private/decorators.py
#   inflating: lambda/numpy/testing/_private/noseclasses.py
#   inflating: lambda/numpy/testing/_private/__init__.py
#   inflating: lambda/numpy/testing/_private/utils.py
#   inflating: lambda/numpy/testing/_private/nosetester.py
#   inflating: lambda/numpy/testing/_private/parameterized.py
#   inflating: lambda/numpy/testing/tests/test_decorators.py
#   inflating: lambda/numpy/testing/tests/__init__.py
#   inflating: lambda/numpy/testing/tests/test_doctesting.py
#   inflating: lambda/numpy/testing/tests/test_utils.py
# Collecting pytz
#   Using cached pytz-2020.1-py2.py3-none-any.whl (510 kB)
# Installing collected packages: pytz
# Successfully installed pytz-2020.1
# WARNING: You are using pip version 20.0.2; however, version 20.2 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.
# Lambda file created: lambda_function.zip

# %% [markdown]
# ----------
#
# ### Building our ML pipeline with the AWS Step Functions Data Science SDK
#
# You are now ready for creating your actual ML pipeline steps. You will start by preparing the training job for Amazon SageMaker, and the data transformation function in AWS Lambda that you created before.

# %%
xgb = sagemaker.estimator.Estimator(
    get_image_uri(boto3.Session().region_name, 'xgboost'),
    sagemaker_execution_role, 
    train_instance_count = 1, 
    train_instance_type = 'ml.m5.xlarge',
    train_volume_size = 5,
    output_path = 's3://{}/{}/output'.format(bucket, prefix),
    sagemaker_session = session
)

xgb.set_hyperparameters(objective='binary:logistic',
                         alpha = 0.0017958870152480393,
                         colsample_bytree = 0.8974444697232986,
                         eta = 0.378416419404957,
                         gamma = 0.0038479366336815115,
                         max_depth = 22,
                         min_child_weight = 3.4445863514152535,
                         num_round = 139,
                         subsample = 0.7432022124726009
                        )

# %%
# SageMaker expects unique names for jobs/models/endpoints. Pass these for each execution via placeholders:
execution_input = ExecutionInput(schema={
    'JobName': str, 
    'ModelName': str
})

# %%
preparation_step = steps.LambdaStep(
    'Preparing data (Lambda)',
    parameters={  
        "FunctionName": "glovo-pre-processing",
        "Payload": {  
           "JobName": execution_input['JobName']
        }
    }
)

preparation_step.add_retry(steps.Retry(
    error_equals=["States.TaskFailed"],
    interval_seconds=15,
    max_attempts=2,
    backoff_rate=4.0
))

# %%
training_step = steps.TrainingStep(
    'Training (SageMaker)', 
    estimator=xgb,
    data={
        'train': sagemaker.s3_input(s3_data='s3://{}/{}/train'.format(bucket, prefix), content_type='csv'),
        'validation': sagemaker.s3_input(s3_data='s3://{}/{}/validation'.format(bucket, prefix), content_type='csv')
    },
    job_name=execution_input['JobName']  
)

# %%
model_step = steps.ModelStep(
    'Save model (SageMaker)',
    model=training_step.get_expected_model(),
    model_name=execution_input['ModelName']  
)

# %% [markdown]
# You will now add another AWS Lambda function for validating the accuracy of your trained model, once the training job completes. In this case, use the metric for the validation loss provided by the Amazon SageMaker XGBoost model by default.

# %%
# Create the validation AWS Lambda:
file_name = 'lambda_function.py'
def MakeFile(file_name):
    with open(file_name, 'w') as f:
        f.write('''\
import json
import boto3
def lambda_handler(event, context):
    sm = boto3.client('sagemaker')
    vloss = sm.describe_training_job(TrainingJobName=event['JobName'])['FinalMetricDataList'][0]['Value']
    print(vloss)
    return {
        'statusCode': 200,
        'vloss': json.dumps(vloss)
    }
        ''')
MakeFile(file_name)

# create the zip file...
with zipfile.ZipFile('lambda_function.zip', 'w', zipfile.ZIP_DEFLATED) as zipObj:
    zipObj.write('lambda_function.py')
# !rm -f lambda_function.py

try:
    f = open("lambda_function.zip")
    print("Lambda file created: lambda_function.zip")
except IOError:
    print("Error - Lambda file not created")
finally:
    f.close()

# Loads the zip file as binary code. 
with open('lambda_function.zip', 'rb') as f: 
    code = f.read()

client = boto3.client('lambda')
create_lambda_function = client.create_function(
    FunctionName = 'glovo-validation',
    Runtime = 'python3.8',
    Role = lambda_role,
    Handler = '{}.lambda_handler'.format('lambda_function'),
    Description = 'Sample ML pipeline validation metric lambda',
    Code = {'ZipFile': code},
    Timeout = 600,
    MemorySize = 128
)
# Out:
# Lambda file created: lambda_function.zip

# %%
validation_lambda_step = steps.LambdaStep(
    'Validating loss (Lambda)',
    parameters={  
        "FunctionName": "glovo-validation",
        "Payload": {  
           "JobName": execution_input['JobName']
        }
    }
)

validation_lambda_step.add_retry(steps.Retry(
    error_equals=["States.TaskFailed"],
    interval_seconds=15,
    max_attempts=2,
    backoff_rate=4.0
))

# %% [markdown]
# For illustrating a typical decision logic that is common in ML workflows, you might want to automate the process of deploying new models to production when new data is available and re-trainings are performed. For example, by comparing the new models’ performance versus a given threshold.
#
# In this example, you decide upon the validation loss whether to continue the ML pipeline for running inferences for the new model in production, or otherwise stop the pipeline if the new model is not meeting the accuracy threshold (set at 3% just for illustrating the concept). This is a mechanism that looks to automate the re-training with new data. For example, you could trigger this ML pipeline everyday with the new data provided from your recent customer's transactions.

# %%
transform_step = steps.TransformStep(
    'Batch inference (SageMaker)',
    transformer=xgb.transformer(
        instance_count=1,
        instance_type='ml.m5.large'
    ),
    job_name=execution_input['JobName'],     
    model_name=execution_input['ModelName'], 
    data='s3://{}/{}/test'.format(bucket, prefix),
    content_type='text/csv',
    split_type='Line'
)

# %%
worse_step = steps.Pass(
    'Worse model',
    parameters={
        "Error": ("The new model is not accurate enough. Validation loss:" + str(validation_lambda_step.output()["Payload"]["vloss"]))
    }
)

# %%
choice_state = steps.Choice(
    state_id='validation loss < 3% ?' #REPLACE with your desired threshold for validation loss
)

# %%
#REPLACE the loss values with your desired threshold
choice_state.add_choice(
    rule=steps.ChoiceRule.StringLessThan(variable=validation_lambda_step.output()["Payload"]["vloss"], value="0.03"),
    next_step=transform_step
)
choice_state.add_choice(
    rule=steps.ChoiceRule.StringGreaterThanEquals(variable=validation_lambda_step.output()["Payload"]["vloss"], value="0.03"),
    next_step=worse_step
)

# %% [markdown]
# Assuming the validation loss is good enough, you can now perform an Amazon SageMaker Batch Transformation for running inferences on all of your testing dataset.
#
# *Note just FYI: In this case you are not creating and 'Endpoint Configuration' and an 'Endpoint', but shall you need it in your use case to respond to real-time inferences you can then follow the steps in the AWS Step Functions Data Science SDK examples, similar to the following lines:*
# ```
# endpoint_config_step = steps.EndpointConfigStep(
#     "Create Endpoint Config",
#     endpoint_config_name=execution_input['ModelName'],
#     model_name=execution_input['ModelName'],
#     initial_instance_count=1,
#     instance_type='ml.m5.large'
# )
#
# endpoint_step = steps.EndpointStep(
#     "Create Endpoint",
#     endpoint_name=execution_input['EndpointName'],
#     endpoint_config_name=execution_input['ModelName']
# )
# ```

# %% [markdown]
# You are now ready for chaining the steps of your ML pipeline with the AWS Step Functions Data Science SDK, and set up the workflow with the create command.

# %%
workflow_definition = steps.Chain([
    preparation_step,
    training_step,
    model_step,
    validation_lambda_step,
    choice_state
])

# %%
workflow = Workflow(
    name='glovo-courier-default',
    definition=workflow_definition,
    role=workflow_execution_role,
    execution_input=execution_input
)

# %%
workflow.render_graph(portrait=False)
# Out:
# <link rel="stylesheet" type="text/css" href="https://do0of8uwbahzz.cloudfront.net/graph.css">
# <div id="graph-947" class="workflowgraph">
#
#     <svg></svg>
#
# </div>
#
# <script type="text/javascript">
#
# require.config({
#     paths: {
#         sfn: "https://do0of8uwbahzz.cloudfront.net/sfn",
#     }
# });
#
# require(['sfn'], function(sfn) {
#     var element = document.getElementById('graph-947')
#
#     var options = {
#         width: parseFloat(getComputedStyle(element, null).width.replace("px", "")),
#         height: 600,
#         layout: 'LR',
#         resizeHeight: true
#     };
#
#     var definition = {"StartAt": "Preparing data (Lambda)", "States": {"Preparing data (Lambda)": {"Parameters": {"FunctionName": "glovo-pre-processing", "Payload": {"JobName.$": "$$.Execution.Input['JobName']"}}, "Resource": "arn:aws:states:::lambda:invoke", "Type": "Task", "Next": "Training (SageMaker)", "Retry": [{"ErrorEquals": ["States.TaskFailed"], "IntervalSeconds": 15, "MaxAttempts": 2, "BackoffRate": 4.0}]}, "Training (SageMaker)": {"Resource": "arn:aws:states:::sagemaker:createTrainingJob.sync", "Parameters": {"AlgorithmSpecification": {"TrainingImage": "685385470294.dkr.ecr.eu-west-1.amazonaws.com/xgboost:1", "TrainingInputMode": "File"}, "OutputDataConfig": {"S3OutputPath": "s3://antonio-rodriguez-workshop/glovo/workflow/output"}, "StoppingCondition": {"MaxRuntimeInSeconds": 86400}, "ResourceConfig": {"InstanceCount": 1, "InstanceType": "ml.m5.xlarge", "VolumeSizeInGB": 5}, "RoleArn": "arn:aws:iam::889960878219:role/service-role/AmazonSageMaker-ExecutionRole-20180920T165537", "InputDataConfig": [{"DataSource": {"S3DataSource": {"S3DataType": "S3Prefix", "S3Uri": "s3://antonio-rodriguez-workshop/glovo/workflow/train", "S3DataDistributionType": "FullyReplicated"}}, "ContentType": "csv", "ChannelName": "train"}, {"DataSource": {"S3DataSource": {"S3DataType": "S3Prefix", "S3Uri": "s3://antonio-rodriguez-workshop/glovo/workflow/validation", "S3DataDistributionType": "FullyReplicated"}}, "ContentType": "csv", "ChannelName": "validation"}], "HyperParameters": {"objective": "binary:logistic", "alpha": "0.0017958870152480393", "colsample_bytree": "0.8974444697232986", "eta": "0.378416419404957", "gamma": "0.0038479366336815115", "max_depth": "22", "min_child_weight": "3.4445863514152535", "num_round": "139", "subsample": "0.7432022124726009"}, "TrainingJobName.$": "$$.Execution.Input['JobName']"}, "Type": "Task", "Next": "Save model (SageMaker)"}, "Save model (SageMaker)": {"Parameters": {"ExecutionRoleArn": "arn:aws:iam::889960878219:role/service-role/AmazonSageMaker-ExecutionRole-20180920T165537", "ModelName.$": "$$.Execution.Input['ModelName']", "PrimaryContainer": {"Environment": {}, "Image": "685385470294.dkr.ecr.eu-west-1.amazonaws.com/xgboost:1", "ModelDataUrl.$": "$['ModelArtifacts']['S3ModelArtifacts']"}}, "Resource": "arn:aws:states:::sagemaker:createModel", "Type": "Task", "Next": "Validating loss (Lambda)"}, "Validating loss (Lambda)": {"Parameters": {"FunctionName": "glovo-validation", "Payload": {"JobName.$": "$$.Execution.Input['JobName']"}}, "Resource": "arn:aws:states:::lambda:invoke", "Type": "Task", "Next": "validation loss < 3% ?", "Retry": [{"ErrorEquals": ["States.TaskFailed"], "IntervalSeconds": 15, "MaxAttempts": 2, "BackoffRate": 4.0}]}, "validation loss < 3% ?": {"Type": "Choice", "Choices": [{"Variable": "$['Payload']['vloss']", "StringLessThan": "0.03", "Next": "Batch inference (SageMaker)"}, {"Variable": "$['Payload']['vloss']", "StringGreaterThanEquals": "0.03", "Next": "Worse model"}]}, "Batch inference (SageMaker)": {"Resource": "arn:aws:states:::sagemaker:createTransformJob.sync", "Parameters": {"TransformJobName.$": "$$.Execution.Input['JobName']", "ModelName.$": "$$.Execution.Input['ModelName']", "TransformInput": {"DataSource": {"S3DataSource": {"S3DataType": "S3Prefix", "S3Uri": "s3://antonio-rodriguez-workshop/glovo/workflow/test"}}, "ContentType": "text/csv", "SplitType": "Line"}, "TransformOutput": {"S3OutputPath": "s3://sagemaker-eu-west-1-889960878219/xgboost-2020-08-04-08-12-17-199"}, "TransformResources": {"InstanceCount": 1, "InstanceType": "ml.m5.large"}}, "Type": "Task", "End": true}, "Worse model": {"Parameters": {"Error": "The new model is not accurate enough. Validation loss:<stepfunctions.inputs.placeholders.StepInput object at 0x7f6a2e4b4400>"}, "Type": "Pass", "End": true}}};
#     var elementId = '#graph-947';
#
#     var graph = new sfn.StateMachineGraph(definition, elementId, options);
#     graph.render();
# });
#
# </script>

# %% [markdown]
# Keep in mind that when you use the SDK in Jupyter notebooks, you define the workflows locally in the notebook instance but **they do not actually exist on AWS Step Functions until the “create” command is called**. Similarly, **these are not executed until the “execute” command is called**, after which you can track its progress on the notebook.

# %%
workflow.create()
# Out:
# [INFO] Workflow created successfully on AWS Step Functions.
# 'arn:aws:states:eu-west-1:889960878219:stateMachine:glovo-courier-default'

# %% [markdown]
# Now you are ready for testing this pipeline by calling the execute command, and debugging its execution logs if necessary.

# %%
execution = workflow.execute(
    inputs={
        'JobName': 'glovo-courier-default-{}'.format(uuid.uuid1().hex), # Each Sagemaker Job requires a unique name
        'ModelName': 'glovo-courier-default-{}'.format(uuid.uuid1().hex), # Each Model requires a unique name
    }
)
# Out:
# [INFO] Workflow execution started successfully on AWS Step Functions.

# %%
execution.render_progress()
# Out:
# <link rel="stylesheet" type="text/css" href="https://do0of8uwbahzz.cloudfront.net/graph.css">
# <div id="graph-575" class="workflowgraph">
#
#     <style>
#         .graph-legend ul {
#             list-style-type: none;
#             padding: 10px;
#             padding-left: 0;
#             margin: 0;
#             position: absolute;
#             top: 0;
#             background: transparent;
#         }
#
#         .graph-legend li {
#             margin-left: 10px;
#             display: inline-block;
#         }
#
#         .graph-legend li > div {
#             width: 10px;
#             height: 10px;
#             display: inline-block;
#         }
#
#         .graph-legend .success { background-color: #2BD62E }
#         .graph-legend .failed { background-color: #DE322F }
#         .graph-legend .cancelled { background-color: #DDDDDD }
#         .graph-legend .in-progress { background-color: #53C9ED }
#         .graph-legend .caught-error { background-color: #FFA500 }
#     </style>
#     <div class="graph-legend">
#         <ul>
#             <li>
#                 <div class="success"></div>
#                 <span>Success</span>
#             </li>
#             <li>
#                 <div class="failed"></div>
#                 <span>Failed</span>
#             </li>
#             <li>
#                 <div class="cancelled"></div>
#                 <span>Cancelled</span>
#             </li>
#             <li>
#                 <div class="in-progress"></div>
#                 <span>In Progress</span>
#             </li>
#             <li>
#                 <div class="caught-error"></div>
#                 <span>Caught Error</span>
#             </li>
#         </ul>
#     </div>
#
#     <svg></svg>
#     <a href="https://console.aws.amazon.com/states/home?region=eu-west-1#/executions/details/arn:aws:states:eu-west-1:889960878219:execution:glovo-courier-default:f2bf6cd1-b875-4edd-93b7-e84e20fe2dd9" target="_blank"> Inspect in AWS Step Functions </a>
# </div>
#
# <script type="text/javascript">
#
# require.config({
#     paths: {
#         sfn: "https://do0of8uwbahzz.cloudfront.net/sfn",
#     }
# });
#
# require(['sfn'], function(sfn) {
#     var element = document.getElementById('graph-575')
#
#     var options = {
#         width: parseFloat(getComputedStyle(element, null).width.replace("px", "")),
#         height: 1000,
#         layout: 'LR',
#         resizeHeight: true
#     };
#
#     var definition = {"StartAt": "Preparing data (Lambda)", "States": {"Preparing data (Lambda)": {"Parameters": {"FunctionName": "glovo-pre-processing", "Payload": {"JobName.$": "$$.Execution.Input['JobName']"}}, "Resource": "arn:aws:states:::lambda:invoke", "Type": "Task", "Next": "Training (SageMaker)", "Retry": [{"ErrorEquals": ["States.TaskFailed"], "IntervalSeconds": 15, "MaxAttempts": 2, "BackoffRate": 4.0}]}, "Training (SageMaker)": {"Resource": "arn:aws:states:::sagemaker:createTrainingJob.sync", "Parameters": {"AlgorithmSpecification": {"TrainingImage": "685385470294.dkr.ecr.eu-west-1.amazonaws.com/xgboost:1", "TrainingInputMode": "File"}, "OutputDataConfig": {"S3OutputPath": "s3://antonio-rodriguez-workshop/glovo/workflow/output"}, "StoppingCondition": {"MaxRuntimeInSeconds": 86400}, "ResourceConfig": {"InstanceCount": 1, "InstanceType": "ml.m5.xlarge", "VolumeSizeInGB": 5}, "RoleArn": "arn:aws:iam::889960878219:role/service-role/AmazonSageMaker-ExecutionRole-20180920T165537", "InputDataConfig": [{"DataSource": {"S3DataSource": {"S3DataType": "S3Prefix", "S3Uri": "s3://antonio-rodriguez-workshop/glovo/workflow/train", "S3DataDistributionType": "FullyReplicated"}}, "ContentType": "csv", "ChannelName": "train"}, {"DataSource": {"S3DataSource": {"S3DataType": "S3Prefix", "S3Uri": "s3://antonio-rodriguez-workshop/glovo/workflow/validation", "S3DataDistributionType": "FullyReplicated"}}, "ContentType": "csv", "ChannelName": "validation"}], "HyperParameters": {"objective": "binary:logistic", "alpha": "0.0017958870152480393", "colsample_bytree": "0.8974444697232986", "eta": "0.378416419404957", "gamma": "0.0038479366336815115", "max_depth": "22", "min_child_weight": "3.4445863514152535", "num_round": "139", "subsample": "0.7432022124726009"}, "TrainingJobName.$": "$$.Execution.Input['JobName']"}, "Type": "Task", "Next": "Save model (SageMaker)"}, "Save model (SageMaker)": {"Parameters": {"ExecutionRoleArn": "arn:aws:iam::889960878219:role/service-role/AmazonSageMaker-ExecutionRole-20180920T165537", "ModelName.$": "$$.Execution.Input['ModelName']", "PrimaryContainer": {"Environment": {}, "Image": "685385470294.dkr.ecr.eu-west-1.amazonaws.com/xgboost:1", "ModelDataUrl.$": "$['ModelArtifacts']['S3ModelArtifacts']"}}, "Resource": "arn:aws:states:::sagemaker:createModel", "Type": "Task", "Next": "Validating loss (Lambda)"}, "Validating loss (Lambda)": {"Parameters": {"FunctionName": "glovo-validation", "Payload": {"JobName.$": "$$.Execution.Input['JobName']"}}, "Resource": "arn:aws:states:::lambda:invoke", "Type": "Task", "Next": "validation loss < 3% ?", "Retry": [{"ErrorEquals": ["States.TaskFailed"], "IntervalSeconds": 15, "MaxAttempts": 2, "BackoffRate": 4.0}]}, "validation loss < 3% ?": {"Type": "Choice", "Choices": [{"Variable": "$['Payload']['vloss']", "StringLessThan": "0.03", "Next": "Batch inference (SageMaker)"}, {"Variable": "$['Payload']['vloss']", "StringGreaterThanEquals": "0.03", "Next": "Worse model"}]}, "Batch inference (SageMaker)": {"Resource": "arn:aws:states:::sagemaker:createTransformJob.sync", "Parameters": {"TransformJobName.$": "$$.Execution.Input['JobName']", "ModelName.$": "$$.Execution.Input['ModelName']", "TransformInput": {"DataSource": {"S3DataSource": {"S3DataType": "S3Prefix", "S3Uri": "s3://antonio-rodriguez-workshop/glovo/workflow/test"}}, "ContentType": "text/csv", "SplitType": "Line"}, "TransformOutput": {"S3OutputPath": "s3://sagemaker-eu-west-1-889960878219/xgboost-2020-08-04-08-12-17-199"}, "TransformResources": {"InstanceCount": 1, "InstanceType": "ml.m5.large"}}, "Type": "Task", "End": true}, "Worse model": {"Parameters": {"Error": "The new model is not accurate enough. Validation loss:<stepfunctions.inputs.placeholders.StepInput object at 0x7f6a2e4b4400>"}, "Type": "Pass", "End": true}}};
#     var elementId = '#graph-575';
#     var events = { 'events': [{"timestamp": 1596528749.371, "type": "ExecutionStarted", "id": 1, "previousEventId": 0, "executionStartedEventDetails": {"input": "{\n    \"JobName\": \"glovo-courier-default-3d4aaccad62a11ea9f35c1c523547daa\",\n    \"ModelName\": \"glovo-courier-default-3d4aae78d62a11ea9f35c1c523547daa\"\n}", "roleArn": "arn:aws:iam::889960878219:role/StepFunctionsWorkflowExecutionRole"}}, {"timestamp": 1596528749.401, "type": "TaskStateEntered", "id": 2, "previousEventId": 0, "stateEnteredEventDetails": {"name": "Preparing data (Lambda)", "input": "{\n    \"JobName\": \"glovo-courier-default-3d4aaccad62a11ea9f35c1c523547daa\",\n    \"ModelName\": \"glovo-courier-default-3d4aae78d62a11ea9f35c1c523547daa\"\n}"}}, {"timestamp": 1596528749.401, "type": "TaskScheduled", "id": 3, "previousEventId": 2, "taskScheduledEventDetails": {"resourceType": "lambda", "resource": "invoke", "region": "eu-west-1", "parameters": "{\"FunctionName\":\"glovo-pre-processing\",\"Payload\":{\"JobName\":\"glovo-courier-default-3d4aaccad62a11ea9f35c1c523547daa\"}}"}}, {"timestamp": 1596528749.438, "type": "TaskStarted", "id": 4, "previousEventId": 3, "taskStartedEventDetails": {"resourceType": "lambda", "resource": "invoke"}}, {"timestamp": 1596528783.519, "type": "TaskSucceeded", "id": 5, "previousEventId": 4, "taskSucceededEventDetails": {"resourceType": "lambda", "resource": "invoke", "output": "{\"ExecutedVersion\":\"$LATEST\",\"Payload\":{\"statusCode\":200,\"body\":\"Date pre-processing complete for joint_dataframe.csv - antonio-rodriguez-workshop/glovo/workflow/joint_dataframe.csv\"},\"SdkHttpMetadata\":{\"AllHttpHeaders\":{\"X-Amz-Executed-Version\":[\"$LATEST\"],\"x-amzn-Remapped-Content-Length\":[\"0\"],\"Connection\":[\"keep-alive\"],\"x-amzn-RequestId\":[\"f3e34451-8705-4013-bb63-3270030e4b90\"],\"Content-Length\":[\"147\"],\"

# %% [markdown]
# *Note you can re-run the previous cell until verifying the execution is completed. It is also possible to verify the execution details directly on the AWS Step Functions console.*
#
# You can also list the events with its details.

# %%
execution.list_events(html=True)
# Out:
#     <style>
#
#     .table-widget {
#         width: 100%;
#         font-size: 14px;
#         line-height: 28px;
#         color: #545b64;
#         border-spacing: 0;
#         background-color: #fff;
#         border-color: grey;
#         background: #fafafa;
#     }
#
#     .table-widget thead th {
#         text-align: left !important;
#         color: #879596;
#         padding: 0.3em 2em;
#         border-bottom: 1px solid #eaeded;
#         min-height: 4rem;
#         line-height: 28px;
#     }
#
#     .table-widget thead th:first-of-type {
#     }
#
#     .table-widget td {
#         overflow-wrap: break-word;
#         padding: 0.4em 2em;
#         line-height: 28px;
#         text-align: left !important;
#         background: #fff;
#         border-bottom: 1px solid #eaeded;
#         border-top: 1px solid transparent;
#     }
#
#     .table-widget td:before {
#         content: "";
#         height: 3rem;
#     }
#
#     a {
#         cursor: pointer;
#         text-decoration: none !important;
#         color: #007dbc;
#     }
#
#     a:hover {
#         text-decoration: underline !important;
#     }
#
#     a.disabled {
#         color: black;
#         cursor: default;
#         pointer-events: none;
#     }
#
#     .hide {
#         display: none;
#     }
#
#     pre {
#         white-space: pre-wrap;
#     }
#
#
#     .table-widget .clickable-cell {
#         padding-left: 0.1em;
#         cursor: pointer;
#     }
#
#     .toggle-icon {
#         display: inline-block;
#         width: 0;
#         height: 0;
#         border-top: 5px solid transparent;
#         border-left: 8px solid #545b64;
#         border-bottom: 5px solid transparent;
#         margin-right: 5px;
#     }
#
#     .toggle-icon.open {
#         -webkit-transform: rotate(90deg);
#         -ms-transform: rotate(90deg);
#         transform: rotate(90deg);
#     }
#
#     </style>
#     <table class="table-widget">
#         <thead>
#             <tr>
#                 <th style="width: 60px">ID</th>
#                 <th>Type</th>
#                 <th>Step</th>
#                 <th>Resource</th>
#                 <th>Elapsed Time (ms)</th>
#                 <th>Timestamp</th>
#             </tr>
#         </thead>
#         <tbody>
#
#     <tr class="awsui-table-row">
#         <td class="awsui-util-pl-xs clickable-cell">
#             <div class="toggle-icon"></div>
#             <span>1</span>
#         </td>
#         <td>ExecutionStarted</td>
#         <td></td>
#         <td><a class='disabled' target="_blank">-</a></td>
#         <td>0.0</td>
#         <td>Aug 04, 2020 08:12:29.371 AM</td>
#     </tr>
#     <tr class="hide">
#         <td class="execution-event-detail" colspan="6">
#             <pre>{
#     "input": {
#         "JobName": "glovo-courier-default-3d4aaccad62a11ea9f35c1c523547daa",
#         "ModelName": "glovo-courier-default-3d4aae78d62a11ea9f35c1c523547daa"
#     },
#     "roleArn": "arn:aws:iam::889960878219:role/StepFunctionsWorkflowExecutionRole"
# }</pre>
#         </td>
#     </tr>
#
#
#     <tr class="awsui-table-row">
#         <td class="awsui-util-pl-xs clickable-cell">
#             <div class="toggle-icon"></div>
#             <span>2</span>
#         </td>
#         <td>TaskStateEntered</td>
#         <td>Preparing data (Lambda)</td>
#         <td><a class='disabled' target="_blank">-</a></td>
#         <td>30.0</td>
#         <td>Aug 04, 2020 08:12:29.401 AM</td>
#     </tr>
#     <tr class="hide">
#         <td class="execution-event-detail" colspan="6">
#             <pre>{
#     "name": "Preparing data (Lambda)",
#     "input": {
#         "JobName": "glovo-courier-default-3d4aaccad62a11ea9f35c1c523547daa",
#         "ModelName": "glovo-courier-default-3d4aae78d62a11ea9f35c1c523547daa"
#     }
# }</pre>
#         </td>
#     </tr>
#
#
#     <tr class="awsui-table-row">
#         <td class="awsui-util-pl-xs clickable-cell">
#             <div class="toggle-icon"></div>
#             <span>3</span>
#         </td>
#         <td>TaskScheduled</td>
#         <td>Preparing data (Lambda)</td>
#         <td><a class='disabled' target="_blank">Step Functions execution</a></td>
#         <td>30.0</td>
#         <td>Aug 04, 2020 08:12:29.401 AM</td>
#     </tr>
#     <tr class="hide">
#         <td class="execution-event-detail" colspan="6">
#             <pre>{
#     "resourceType": "lambda",
#     "resource": "invoke",
#     "region": "eu-west-1",
#     "parameters": {
#         "FunctionName": "glovo-pre-processing",
#         "Payload": {
#             "JobName": "glovo-courier-default-3d4aaccad62a11ea9f35c1c523547daa"
#         }
#     }
# }</pre>
#         </td>
#     </tr>
#
#
#     <tr class="awsui-table-row">
#         <td class="awsui-util-pl-xs clickable-cell">
#             <div class="toggle-icon"></div>
#             <span>4</span>
#         </td>
#         <td>TaskStarted</td>
#         <td>Preparing data (Lambda)</td>
#         <td><a class='disabled' target="_blank">Step Functions execution</a></td>
#         <td>67.0</td>
#         <td>Aug 04, 2020 08:12:29.438 AM</td>
#     </tr>
#     <tr class="hide">
#         <td class="execution-event-detail" colspan="6">
#             <pre>{
#     "resourceType": "lambda",
#     "resource": "invoke"
# }</pre>
#         </td>
#     </tr>
#
#
#     <tr class="awsui-table-row">
#         <td class="awsui-util-pl-xs clickable-cell">
#             <div class="toggle-icon"></div>
#             <span>5</span>
#         </td>
#         <td>TaskSucceeded</td>
#         <td>Preparing data (Lambda)</td>
#         <td><a class='disabled' target="_blank">Step Functions execution</a></td>
#         <td>148.0</td>
#         <td>Aug 04, 2020 08:13:03.519 AM</td>
#     </tr>
#     <tr class="hide">
#         <td class="execution-event-detail" colspan="6">
#             <pre>{
#     "resourceType": "lambda",
#     "resource": "invoke",
#     "output": {
#         "ExecutedVersion": "$LATEST",
#         "Payload": {
#             "statusCode": 200,
#             "body": "Date pre-processing complete for joint_dataframe.csv - antonio-rodriguez-workshop/glovo/workflow/joint_dataframe.csv"
#         },
#         "SdkHttpMetadata": {
#             "AllHttpHeaders": {
#                 "X-Amz-Executed-Version": [
#                     "$LATEST"
#                 ],
#                 "x-amzn-Remapped-Content-Length": [
#                     "0"
#                 ],
#                 "Connection": [
#                     "keep-alive"
#                 ],
#                 "x-amzn-RequestId": [
#                     "f3e34451-8705-4013-bb63-3270030e4b90"
#                 ],
#                 "Content-Length": [
#                     "147"
#                 ],
#                 "Date": [
#                     "Tue, 04 Aug 2020 08:13:03 GMT"
#                 ],
#                 "X-Amzn-Trace-Id": [
#                     "root=1-5f29186d-7be2259c727079380f986fe6;sampled=0"
#                 ],
#                 "Content-Type": [
#                     "application/json"
#                 ]
#             },
#             "HttpHeaders": {
#                 "Connection": "keep-alive",
#                 "Content-Length": "147",
#                 "Content-Type": "application/json",
#                 "Date": "Tue, 04 Aug 2020 08:13:03 GMT",
#                 "X-Amz-Executed-Version": "$LATEST",
#                 "x-amzn-Remapped-Content-Length": "0",
#                 "x-amzn-RequestId": "f3e34451-8705-4013-bb63-3270030e4b90",
#                 "X-Amzn-Trace-Id": "root=1-5f29186d-7be2259c727079380f986fe6;sampled=0"
#             },
#             "HttpStatusCode": 200
#         },
#         "SdkResponseMetadata": {
#             "RequestId": "f3e34451-8705-4013-bb63-3270030e4b90"
#         },
#         "StatusCode": 200
#     }
# }</pre>
#         </td>
#     </tr>
#
#
#     <tr class="awsui-table-row">
#         <td class="awsui-util-pl-xs clickable-cell">
#             <div class="toggle-icon"></div>
#             <span>6</span>
#         </td>
#         <td>TaskStateExited</td>
#         <td>Preparing data (Lambda)</td>
#         <td><a class='disabled' target="_blank">-</a></td>
#         <td>148.0</td>
#         <td>Aug 04, 2020 08:13:03.519 AM</td>
#     </tr>
#     <tr class="hide">
#         <td class="execution-event-detail" colspan="6">
#             <pre>{
#     "name": "Preparing data (Lambda)",
#     "output": {
#         "ExecutedVersion": "$LATEST",
#         "Payload": {
#             "statusCode":

# %%
workflow.list_executions(html=True)
# Out:
#     <style>
#
#     .table-widget {
#         width: 100%;
#         font-size: 14px;
#         line-height: 28px;
#         color: #545b64;
#         border-spacing: 0;
#         background-color: #fff;
#         border-color: grey;
#         background: #fafafa;
#     }
#
#     .table-widget thead th {
#         text-align: left !important;
#         color: #879596;
#         padding: 0.3em 2em;
#         border-bottom: 1px solid #eaeded;
#         min-height: 4rem;
#         line-height: 28px;
#     }
#
#     .table-widget thead th:first-of-type {
#     }
#
#     .table-widget td {
#         overflow-wrap: break-word;
#         padding: 0.4em 2em;
#         line-height: 28px;
#         text-align: left !important;
#         background: #fff;
#         border-bottom: 1px solid #eaeded;
#         border-top: 1px solid transparent;
#     }
#
#     .table-widget td:before {
#         content: "";
#         height: 3rem;
#     }
#
#     a {
#         cursor: pointer;
#         text-decoration: none !important;
#         color: #007dbc;
#     }
#
#     a:hover {
#         text-decoration: underline !important;
#     }
#
#     a.disabled {
#         color: black;
#         cursor: default;
#         pointer-events: none;
#     }
#
#     .hide {
#         display: none;
#     }
#
#     pre {
#         white-space: pre-wrap;
#     }
#
#
#     * {
#         box-sizing: border-box;
#     }
#
#     .table-widget {
#         min-width: 100%;
#         font-size: 14px;
#         line-height: 28px;
#         color: #545b64;
#         border-spacing: 0;
#         background-color: #fff;
#         border-color: grey;
#         background: #fafafa;
#     }
#
#     .table-widget thead th {
#         text-align: left !important;
#         color: #879596;
#         padding: 0.3em 2em;
#         border-bottom: 1px solid #eaeded;
#         min-height: 4rem;
#         line-height: 28px;
#     }
#
#     .table-widget td {
#         /* padding: 24px 18px; */
#         padding: 0.4em 2em;
#         line-height: 28px;
#         text-align: left !important;
#         background: #fff;
#         border-bottom: 1px solid #eaeded;
#         border-top: 1px solid transparent;
#     }
#
#     .table-widget td:before {
#         content: "";
#         height: 3rem;
#     }
#
#     .table-widget .clickable-cell {
#         cursor: pointer;
#     }
#
#     .hide {
#         display: none;
#     }
#
#     .triangle-right {
#         width: 0;
#         height: 0;
#         border-top: 5px solid transparent;
#         border-left: 8px solid #545b64;
#         border-bottom: 5px solid transparent;
#         margin-right: 5px;
#     }
#
#     a.awsui {
#         text-decoration: none !important;
#         color: #007dbc;
#     }
#
#     a.awsui:hover {
#         text-decoration: underline !important;
#     }
#
#     </style>
#     <table class="table-widget">
#         <thead>
#             <tr>
#                 <th>Name</th>
#                 <th>Status</th>
#                 <th>Started</th>
#                 <th>End Time</th>
#             </tr>
#         </thead>
#         <tbody>
#
#     <tr class="awsui-table-row">
#         <td>
#             <a href="https://console.aws.amazon.com/states/home?region=eu-west-1#/executions/details/arn:aws:states:eu-west-1:889960878219:execution:glovo-courier-default:f2bf6cd1-b875-4edd-93b7-e84e20fe2dd9" target="_blank" class="awsui">f2bf6cd1-b875-4edd-93b7-e84e20fe2dd9</a>
#         </td>
#         <td>SUCCEEDED</td>
#         <td>Aug 04, 2020 08:12:29.371 AM</td>
#         <td>Aug 04, 2020 08:19:22.056 AM</td>
#     </tr>
#
#         </tbody>
#     </table>

# %%
workflow.list_workflows(html=True)
# Out:
#     <style>
#
#     .table-widget {
#         width: 100%;
#         font-size: 14px;
#         line-height: 28px;
#         color: #545b64;
#         border-spacing: 0;
#         background-color: #fff;
#         border-color: grey;
#         background: #fafafa;
#     }
#
#     .table-widget thead th {
#         text-align: left !important;
#         color: #879596;
#         padding: 0.3em 2em;
#         border-bottom: 1px solid #eaeded;
#         min-height: 4rem;
#         line-height: 28px;
#     }
#
#     .table-widget thead th:first-of-type {
#     }
#
#     .table-widget td {
#         overflow-wrap: break-word;
#         padding: 0.4em 2em;
#         line-height: 28px;
#         text-align: left !important;
#         background: #fff;
#         border-bottom: 1px solid #eaeded;
#         border-top: 1px solid transparent;
#     }
#
#     .table-widget td:before {
#         content: "";
#         height: 3rem;
#     }
#
#     a {
#         cursor: pointer;
#         text-decoration: none !important;
#         color: #007dbc;
#     }
#
#     a:hover {
#         text-decoration: underline !important;
#     }
#
#     a.disabled {
#         color: black;
#         cursor: default;
#         pointer-events: none;
#     }
#
#     .hide {
#         display: none;
#     }
#
#     pre {
#         white-space: pre-wrap;
#     }
#
#
#     * {
#         box-sizing: border-box;
#     }
#
#     .table-widget {
#         min-width: 100%;
#         font-size: 14px;
#         line-height: 28px;
#         color: #545b64;
#         border-spacing: 0;
#         background-color: #fff;
#         border-color: grey;
#         background: #fafafa;
#     }
#
#     .table-widget thead th {
#         text-align: left !important;
#         color: #879596;
#         padding: 0.3em 2em;
#         border-bottom: 1px solid #eaeded;
#         min-height: 4rem;
#         line-height: 28px;
#     }
#
#     .table-widget td {
#         /* padding: 24px 18px; */
#         padding: 0.4em 2em;
#         line-height: 28px;
#         text-align: left !important;
#         background: #fff;
#         border-bottom: 1px solid #eaeded;
#         border-top: 1px solid transparent;
#     }
#
#     .table-widget td:before {
#         content: "";
#         height: 3rem;
#     }
#
#     .table-widget .clickable-cell {
#         cursor: pointer;
#     }
#
#     .hide {
#         display: none;
#     }
#
#     .triangle-right {
#         width: 0;
#         height: 0;
#         border-top: 5px solid transparent;
#         border-left: 8px solid #545b64;
#         border-bottom: 5px solid transparent;
#         margin-right: 5px;
#     }
#
#     a.awsui {
#         text-decoration: none !important;
#         color: #007dbc;
#     }
#
#     a.awsui:hover {
#         text-decoration: underline !important;
#     }
#
#     </style>
#     <table class="table-widget">
#         <thead>
#             <tr>
#                 <th>Name</th>
#                 <th>Creation Date</th>
#             </tr>
#         </thead>
#         <tbody>
#
#     <tr class="awsui-table-row">
#         <td>
#             <a href="https://console.aws.amazon.com/states/home?region=eu-west-1#/statemachines/view/arn:aws:states:eu-west-1:889960878219:stateMachine:WorkshopMgmtManageAccounts" target="_blank" class="awsui">WorkshopMgmtManageAccounts</a>
#         </td>
#         <td>Oct 14, 2019 02:05:27.801 PM</td>
#     </tr>
#
#
#     <tr class="awsui-table-row">
#         <td>
#             <a href="https://console.aws.amazon.com/states/home?region=eu-west-1#/statemachines/view/arn:aws:states:eu-west-1:889960878219:stateMachine:glovo-courier-default" target="_blank" class="awsui">glovo-courier-default</a>
#         </td>
#         <td>Aug 04, 2020 08:12:27.975 AM</td>
#     </tr>
#
#
#     <tr class="awsui-table-row">
#         <td>
#             <a href="https://console.aws.amazon.com/states/home?region=eu-west-1#/statemachines/view/arn:aws:states:eu-west-1:889960878219:stateMachine:glovo-workflow" target="_blank" class="awsui">glovo-workflow</a>
#         </td>
#         <td>Jul 31, 2020 03:16:35.290 PM</td>
#     </tr>
#
#
#     <tr class="awsui-table-row">
#         <td>
#             <a href="https://console.aws.amazon.com/states/home?region=eu-west-1#/statemachines/view/arn:aws:states:eu-west-1:889960878219:stateMachine:ml-pipelines-sample-price-estimation_v1" target="_blank" class="awsui">ml-pipelines-sample-price-estimation_v1</a>
#         </td>
#         <td>May 11, 2020 11:57:59.991 AM</td>
#     </tr>
#
#
#     <tr class="awsui-table-row">
#         <td>
#             <a href="https://console.aws.amazon.com/states/home?region=eu-west-1#/statemachines/view/arn:aws:states:eu-west-1:889960878219:stateMachine:training-pipeline-2019-11-15-13-57-27" target="_blank" class="awsui">training-pipeline-2019-11-15-13-57-27</a>
#         </td>
#         <td>Nov 15, 2019 01:58:50.548 PM</td>
#     </tr>
#
#         </tbody>
#     </table>

# %% [markdown]
# You can even export the AWS CloudFormation template for the pipeline you have just built, in order to deploy it later on as infrastructure as code if required.

# %%
print(Workflow.get_cloudformation_template(workflow))
# Out:
# [WARNING] To reuse the CloudFormation template in different regions, please make sure to update the region specific AWS resources in the StateMachine definition.
# AWSTemplateFormatVersion: '2010-09-09'
# Description: CloudFormation template for AWS Step Functions - State Machine
# Resources:
#   StateMachineComponent:
#     Type: AWS::StepFunctions::StateMachine
#     Properties:
#       StateMachineName: glovo-courier-default
#       DefinitionString: |-
#         {
#           "StartAt": "Preparing data (Lambda)",
#           "States": {
#             "Preparing data (Lambda)": {
#               "Parameters": {
#                 "FunctionName": "glovo-pre-processing",
#                 "Payload": {
#                   "JobName.$": "$$.Execution.Input['JobName']"
#                 }
#               },
#               "Resource": "arn:aws:states:::lambda:invoke",
#               "Type": "Task",
#               "Next": "Training (SageMaker)",
#               "Retry": [
#                 {
#                   "ErrorEquals": [
#                     "States.TaskFailed"
#                   ],
#                   "IntervalSeconds": 15,
#                   "MaxAttempts": 2,
#                   "BackoffRate": 4.0
#                 }
#               ]
#             },
#             "Training (SageMaker)": {
#               "Resource": "arn:aws:states:::sagemaker:createTrainingJob.sync",
#               "Parameters": {
#                 "AlgorithmSpecification": {
#                   "TrainingImage": "685385470294.dkr.ecr.eu-west-1.amazonaws.com/xgboost:1",
#                   "TrainingInputMode": "File"
#                 },
#                 "OutputDataConfig": {
#                   "S3OutputPath": "s3://antonio-rodriguez-workshop/glovo/workflow/output"
#                 },
#                 "StoppingCondition": {
#                   "MaxRuntimeInSeconds": 86400
#                 },
#                 "ResourceConfig": {
#                   "InstanceCount": 1,
#                   "InstanceType": "ml.m5.xlarge",
#                   "VolumeSizeInGB": 5
#                 },
#                 "RoleArn": "arn:aws:iam::889960878219:role/service-role/AmazonSageMaker-ExecutionRole-20180920T165537",
#                 "InputDataConfig": [
#                   {
#                     "DataSource": {
#                       "S3DataSource": {
#                         "S3DataType": "S3Prefix",
#                         "S3Uri": "s3://antonio-rodriguez-workshop/glovo/workflow/train",
#                         "S3DataDistributionType": "FullyReplicated"
#                       }
#                     },
#                     "ContentType": "csv",
#                     "ChannelName": "train"
#                   },
#                   {
#                     "DataSource": {
#                       "S3DataSource": {
#                         "S3DataType": "S3Prefix",
#                         "S3Uri": "s3://antonio-rodriguez-workshop/glovo/workflow/validation",
#                         "S3DataDistributionType": "FullyReplicated"
#                       }
#                     },
#                     "ContentType": "csv",
#                     "ChannelName": "validation"
#                   }
#                 ],
#                 "HyperParameters": {
#                   "objective": "binary:logistic",
#                   "alpha": "0.0017958870152480393",
#                   "colsample_bytree": "0.8974444697232986",
#                   "eta": "0.378416419404957",
#                   "gamma": "0.0038479366336815115",
#                   "max_depth": "22",
#                   "min_child_weight": "3.4445863514152535",
#                   "num_round": "139",
#                   "subsample": "0.7432022124726009"
#                 },
#                 "TrainingJobName.$": "$$.Execution.Input['JobName']"
#               },
#               "Type": "Task",
#               "Next": "Save model (SageMaker)"
#             },
#             "Save model (SageMaker)": {
#               "Parameters": {
#                 "ExecutionRoleArn": "arn:aws:iam::889960878219:role/service-role/AmazonSageMaker-ExecutionRole-20180920T165537",
#                 "ModelName.$": "$$.Execution.Input['ModelName']",
#                 "PrimaryContainer": {
#                   "Environment": {},
#                   "Image": "685385470294.dkr.ecr.eu-west-1.amazonaws.com/xgboost:1",
#                   "ModelDataUrl.$": "$['ModelArtifacts']['S3ModelArtifacts']"
#                 }
#               },
#               "Resource": "arn:aws:states:::sagemaker:createModel",
#               "Type": "Task",
#               "Next": "Validating loss (Lambda)"
#             },
#             "Validating loss (Lambda)": {
#               "Parameters": {
#                 "FunctionName": "glovo-validation",
#                 "Payload": {
#                   "JobName.$": "$$.Execution.Input['JobName']"
#                 }
#               },
#               "Resource": "arn:aws:states:::lambda:invoke",
#               "Type": "Task",
#               "Next": "validation loss < 3% ?",
#               "Retry": [
#                 {
#                   "ErrorEquals": [
#                     "States.TaskFailed"
#                   ],
#                   "IntervalSeconds": 15,
#                   "MaxAttempts": 2,
#                   "BackoffRate": 4.0
#                 }
#               ]
#             },
#             "validation loss < 3% ?": {
#               "Type": "Choice",
#               "Choices": [
#                 {
#                   "Variable": "$['Payload']['vloss']",
#                   "StringLessThan": "0.03",
#                   "Next": "Batch inference (SageMaker)"
#                 },
#                 {
#                   "Variable": "$['Payload']['vloss']",
#                   "StringGreaterThanEquals": "0.03",
#                   "Next": "Worse model"
#                 }
#               ]
#             },
#             "Batch inference (SageMaker)": {
#               "Resource": "arn:aws:states:::sagemaker:createTransformJob.sync",
#               "Parameters": {
#                 "TransformJobName.$": "$$.Execution.Input['JobName']",
#                 "ModelName.$": "$$.Execution.Input['ModelName']",
#                 "TransformInput": {
#                   "DataSource": {
#                     "S3DataSource": {
#                       "S3DataType": "S3Prefix",
#                       "S3Uri": "s3://antonio-rodriguez-workshop/glovo/workflow/test"
#                     }
#                   },
#                   "ContentType": "text/csv",
#                   "SplitType": "Line"
#                 },
#                 "TransformOutput": {
#                   "S3OutputPath": "s3://sagemaker-eu-west-1-889960878219/xgboost-2020-08-04-08-12-17-199"
#                 },
#                 "TransformResources": {
#                   "InstanceCount": 1,
#                   "InstanceType": "ml.m5.large"
#                 }
#               },
#               "Type": "Task",
#               "End": true
#             },
#             "Worse model": {
#               "Parameters": {
#                 "Error": "The new model is not accurate enough. Validation loss:<stepfunctions.inputs.placeholders.StepInput object at 0x7f6a2e4b4400>"
#               },
#               "Type": "Pass",
#               "End": true
#             }
#           }
#         }
#       RoleArn: arn:aws:iam::889960878219:role/StepFunctionsWorkflowExecutionRole
